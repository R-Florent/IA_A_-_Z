# %%
import torch
import torchvision
import torchvision.transforms as transforms


import numpy as np

import torch.optim as optim
from sympy.codegen.ast import none
from torch.utils.data import dataloader

from torch.utils.data import random_split, DataLoader

import threading

from agents.Classe_agent import Agent
from metrics import metrics_plot
from topologies.NetworkTopology import NetworkTopology

from models.model import Net,AlexNet

from training.plot_benchmark_results import plot_all_benchmark_metrics
from training.plot_benchmark_results import print_benchmark_summary

from metrics.metrics import plot_average_distance, node_weight_metric

from metrics.metrics import plot_cumulative_times ,plot_all_agent_node_weight_metric,plot_distance_heatmap,plot_cosine_similarity,plot_epoch_times

from metrics.Classe_model_metrics import ModelMetrics
#from metrics.plot_benchmark import*
from synchronize_weight import*
from training.scrpit_generate_agent import generate_agent
from training.scrpit_train_agent_sequential import benchmark_sequential
from hyperparametres import *
from ExperimentRunner import ExperimentRunner

# %%
# --- hyperparamètres ---

RANDOM_SEED = 123
BATCH_SIZE = 10
NUM_EPOCHES = 60

MOMENTUM = 0.9
LEARING_RATE = 0.001
SCALE = 0.1
IMG_SIZE = (128, 128)
LATENT_DIM = 10
N_AGENT = 10
k = 5
# Device configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.version
torch.version.cuda
torch.cuda.is_available()

agent_list = generate_agent(BATCH_SIZE,N_AGENT,DEVICE)
# Out:
# C:\Users\flofl\PycharmProjects\IA_A_à_Z\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550

# %%
def Consensus_step_fully_connected_graph(agent_list, graph, k, epoch, num_epochs,comm_cost=None):
    graph = NetworkTopology.fully_connected_graph(len(agent_list))
    Average_consensus_algorithm(agent_list, graph, comm_cost=comm_cost)

def Consensus_step_cycle_graph(agent_list, graph, k, epoch, num_epochs,comm_cost=None):
    graph = NetworkTopology.cycle_graph(len(agent_list))
    Average_consensus_algorithm(agent_list, graph, comm_cost=comm_cost)

def Consensus_step_star_graph(agent_list, graph, k, epoch, num_epochs,comm_cost=None):
    graph = NetworkTopology.star_graph(len(agent_list))
    Average_consensus_algorithm(agent_list, graph, comm_cost=comm_cost)

def Consensus_step_random_graph(agent_list, graph, k, epoch, num_epochs,comm_cost=None):
    graph = NetworkTopology.random_graph(len(agent_list))
    Average_consensus_algorithm(agent_list, graph, comm_cost=comm_cost)

# ──────────────────────────────────────────────────────────────
# Dictionnaire des méthodes à comparer
# ──────────────────────────────────────────────────────────────

COMMUNICATION_METHODS = {
    f"AC_fully_connected_graph" : Consensus_step_fully_connected_graph,
    f"AC_cycle_graph)"          : Consensus_step_cycle_graph,
    f"AC_star_graph"            : Consensus_step_star_graph,
    f"AC_random_graph"          : Consensus_step_random_graph
}

results,comparator = benchmark_sequential(
    communication_methods=COMMUNICATION_METHODS,
    num_epochs=NUM_EPOCHES,
    graph=none,
    k=k,
    BATCH_SIZE=BATCH_SIZE,
    N_AGENT=N_AGENT,
    DEVICE=DEVICE,
)
# Out:
# ============================================================
#   RUN — méthode : CS_fully_connected_graph
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/30] threads started …
# Agent 4 start
# Agent 3 start
# Agent 1 start
# Agent 6 start
# Agent 2 start
# Agent 5 start
# Agent 9 start
# Agent 8 start
# Agent 0 start
# Agent 7 start
# Model4 - Acc:12.7 % - Loss:2.301365615367889 %
# Model3 - Acc:10.46 % - Loss:2.303604552268982 %
# Model2 - Acc:12.12 % - Loss:2.3003857178688047 %
# Model5 - Acc:11.4 % - Loss:2.300332817554474 %
# Model1 - Acc:10.04 % - Loss:2.3016806650161743 %
# Model6 - Acc:11.62 % - Loss:2.3013555746078493 %
# Model9 - Acc:11.58 % - Loss:2.301628201007843 %
# Model8 - Acc:10.54 % - Loss:2.302410465717316 %
# Model0 - Acc:9.34 % - Loss:2.3034406747817995 %
# Model7 - Acc:10.36 % - Loss:2.302510482788086 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=0 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 1/30] ✓  time=54.47s  cumulative=54.47s
#   [Epoch 2/30] threads started …
# Agent 1 start
# Agent 8 start
# Agent 0 start
# Agent 2 start
# Agent 3 start
# Agent 9 start
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Model1 - Acc:10.3 % - Loss:2.302710672855377 %
# Model8 - Acc:11.08 % - Loss:2.30263769197464 %
# Model0 - Acc:9.28 % - Loss:2.3029961199760436 %
# Model2 - Acc:10.04 % - Loss:2.302755253314972 %
# Model3 - Acc:10.22 % - Loss:2.302545359611511 %
# Model9 - Acc:9.62 % - Loss:2.3029070987701417 %
# Model7 - Acc:10.12 % - Loss:2.3027348499298097 %
# Model6 - Acc:10.22 % - Loss:2.302934540271759 %
# Model4 - Acc:9.86 % - Loss:2.302613609790802 %
# Model5 - Acc:9.62 % - Loss:2.3029653058052064 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=1 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 2/30] ✓  time=49.18s  cumulative=103.65s
#   [Epoch 3/30] threads started …
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 9 start
# Agent 8 start
# Agent 1 start
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Model5 - Acc:9.68 % - Loss:2.3029110960960386 %
# Model3 - Acc:10.54 % - Loss:2.302622115135193 %
# Model4 - Acc:9.9 % - Loss:2.3026476850509643 %
# Model2 - Acc:9.54 % - Loss:2.302728361129761 %
# Model9 - Acc:10.28 % - Loss:2.302846322059631 %
# Model1 - Acc:10.08 % - Loss:2.302708837032318 %
# Model8 - Acc:11.08 % - Loss:2.30256875038147 %
# Model0 - Acc:9.52 % - Loss:2.302887239933014 %
# Model6 - Acc:9.92 % - Loss:2.3029110751152038 %
# Model7 - Acc:9.8 % - Loss:2.302729156970978 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=2 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 3/30] ✓  time=48.38s  cumulative=152.03s
#   [Epoch 4/30] threads started …
# Agent 6 start
# Agent 7 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 1 start
# Agent 8 start
# Agent 3 start
# Agent 9 start
# Agent 0 start
# Model6 - Acc:9.62 % - Loss:2.3029253549575808 %
# Model7 - Acc:9.94 % - Loss:2.3027295746803285 %
# Model5 - Acc:9.68 % - Loss:2.3028523283004763 %
# Model4 - Acc:10.26 % - Loss:2.30264750957489 %
# Model2 - Acc:10.28 % - Loss:2.3026388940811158 %
# Model1 - Acc:10.52 % - Loss:2.3027140827178956 %
# Model8 - Acc:10.94 % - Loss:2.302629442214966 %
# Model3 - Acc:10.3 % - Loss:2.302579412460327 %
# Model0 - Acc:9.52 % - Loss:2.3028406896591185 %
# Model9 - Acc:9.76 % - Loss:2.3028214440345764 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=3 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 4/30] ✓  time=45.22s  cumulative=197.25s
#   [Epoch 5/30] threads started …
# Agent 0 start
# Agent 6 start
# Agent 1 start
# Agent 9 start
# Agent 8 start
# Agent 7 start
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Agent 5 start
# Model0 - Acc:9.16 % - Loss:2.3028647565841673 %
# Model6 - Acc:9.36 % - Loss:2.3029100217819214 %
# Model9 - Acc:9.42 % - Loss:2.302780788898468 %
# Model1 - Acc:10.34 % - Loss:2.302778908252716 %
# Model8 - Acc:10.78 % - Loss:2.3026045532226562 %
# Model7 - Acc:9.38 % - Loss:2.302682106018066 %
# Model2 - Acc:10.0 % - Loss:2.3026241235733034 %
# Model4 - Acc:9.82 % - Loss:2.302687520980835 %
# Model3 - Acc:9.88 % - Loss:2.302602030277252 %
# Model5 - Acc:9.14 % - Loss:2.302886198043823 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=4 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 5/30] ✓  time=45.50s  cumulative=242.75s
#   [Epoch 6/30] threads started …
# Agent 8 start
# Agent 7 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 2 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Agent 3 start
# Model8 - Acc:10.96 % - Loss:2.3026310415267943 %
# Model7 - Acc:9.68 % - Loss:2.302734431743622 %
# Model1 - Acc:10.72 % - Loss:2.302670560836792 %
# Model0 - Acc:9.4 % - Loss:2.3027544260025024 %
# Model9 - Acc:9.86 % - Loss:2.302823924541473 %
# Model2 - Acc:10.32 % - Loss:2.3025972023010253 %
# Model4 - Acc:9.94 % - Loss:2.302736936569214 %
# Model6 - Acc:9.4 % - Loss:2.3028866152763365 %
# Model5 - Acc:9.7 % - Loss:2.3028120727539063 %
# Model3 - Acc:10.2 % - Loss:2.302589426040649 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=5 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 6/30] ✓  time=45.94s  cumulative=288.70s
#   [Epoch 7/30] threads started …
# Agent 9 start
# Agent 1 start
# Agent 2 start
# Agent 3 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Agent 7 start
# Agent 0 start
# Agent 8 start
# Model9 - Acc:9.6 % - Loss:2.3027771382331848 %
# Model1 - Acc:10.32 % - Loss:2.3027036399841307 %
# Model2 - Acc:9.38 % - Loss:2.302658712387085 %
# Model3 - Acc:10.16 % - Loss:2.3026347661018374 %
# Model4 - Acc:9.78 % - Loss:2.3027313017845152 %
# Model6 - Acc:9.38 % - Loss:2.3029300417900087 %
# Model5 - Acc:10.16 % - Loss:2.302785415172577 %
# Model7 - Acc:9.16 % - Loss:2.302726963996887 %
# Model0 - Acc:9.8 % - Loss:2.3027736954689026 %
# Model8 - Acc:10.56 % - Loss:2.302666311740875 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=6 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 7/30] ✓  time=46.14s  cumulative=334.83s
#   [Epoch 8/30] threads started …
# Agent 4 start
# Agent 3 start
# Agent 6 start
# Agent 5 start
# Agent 7 start
# Agent 8 start
# Agent 1 start
# Agent 2 start
# Agent 0 start
# Agent 9 start
# Model4 - Acc:10.04 % - Loss:2.302694108009338 %
# Model3 - Acc:10.4 % - Loss:2.3025840334892274 %
# Model6 - Acc:9.3 % - Loss:2.3029097294807435 %
# Model5 - Acc:9.5 % - Loss:2.3028752784729005 %
# Model7 - Acc:9.48 % - Loss:2.302705237865448 %
# Model8 - Acc:11.0 % - Loss:2.3026571946144103 %
# Model1 - Acc:10.42 % - Loss:2.302611346244812 %
# Model2 - Acc:9.5 % - Loss:2.3026250290870665 %
# Model0 - Acc:9.94 % - Loss:2.302789183139801 %
# Model9 - Acc:9.7 % - Loss:2.3027839593887327 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=7 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 8/30] ✓  time=46.66s  cumulative=381.49s
#   [Epoch 9/30] threads started …
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Agent 5 start
# Agent 0 start
# Agent 3 start
# Agent 8 start
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Model6 - Acc:9.9 % - Loss:2.3029081158638 %
# Model4 - Acc:10.08 % - Loss:2.3027299246788027 %
# Model7 - Acc:9.04 % - Loss:2.3026976709365843 %
# Model5 - Acc:9.16 % - Loss:2.3028664445877074 %
# Model0 - Acc:9.0 % - Loss:2.3027920570373537 %
# Model3 - Acc:9.78 % - Loss:2.3026526880264284 %
# Model8 - Acc:10.6 % - Loss:2.3027454657554625 %
# Model1 - Acc:10.5 % - Loss:2.302674033641815 %
# Model9 - Acc:10.32 % - Loss:2.3028308267593385 %
# Model2 - Acc:10.34 % - Loss:2.3026282987594606 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=8 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 9/30] ✓  time=45.19s  cumulative=426.68s
#   [Epoch 10/30] threads started …
# Agent 7 start
# Agent 0 start
# Agent 1 start
# Agent 6 start
# Agent 9 start
# Agent 8 start
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Model7 - Acc:9.42 % - Loss:2.3027251420021058 %
# Model0 - Acc:9.54 % - Loss:2.3027907953262328 %
# Model1 - Acc:10.58 % - Loss:2.3026861419677735 %
# Model6 - Acc:8.94 % - Loss:2.302916769981384 %
# Model9 - Acc:9.98 % - Loss:2.3027683157920835 %
# Model8 - Acc:10.82 % - Loss:2.3026830625534056 %
# Model3 - Acc:9.86 % - Loss:2.302687234401703 %
# Model5 - Acc:10.22 % - Loss:2.3028389534950255 %
# Model4 - Acc:9.56 % - Loss:2.3027545042037962 %
# Model2 - Acc:9.68 % - Loss:2.302650499820709 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=9 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 10/30] ✓  time=44.56s  cumulative=471.25s
#   [Epoch 11/30] threads started …
# Agent 1 start
# Agent 3 start
# Agent 0 start
# Agent 2 start
# Agent 9 start
# Agent 8 start
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Agent 5 start
# Model1 - Acc:10.46 % - Loss:2.3026778922080995 %
# Model3 - Acc:9.5 % - Loss:2.3026670670509337 %
# Model0 - Acc:9.5 % - Loss:2.3028056268692016 %
# Model2 - Acc:9.86 % - Loss:2.3027073674201963 %
# Model9 - Acc:9.84 % - Loss:2.3028119745254516 %
# Model8 - Acc:10.5 % - Loss:2.3027300000190736 %
# Model6 - Acc:9.38 % - Loss:2.3029191880226136 %
# Model4 - Acc:9.8 % - Loss:2.302700846672058 %
# Model7 - Acc:9.76 % - Loss:2.3027073392868043 %
# Model5 - Acc:10.28 % - Loss:2.3028271155357363 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=10 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 11/30] ✓  time=45.74s  cumulative=516.98s
#   [Epoch 12/30] threads started …
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Agent 5 start
# Agent 1 start
# Agent 9 start
# Agent 6 start
# Agent 7 start
# Agent 0 start
# Agent 8 start
# Model2 - Acc:10.0 % - Loss:2.3026549496650697 %
# Model4 - Acc:9.58 % - Loss:2.302714164733887 %
# Model3 - Acc:10.0 % - Loss:2.302619643688202 %
# Model5 - Acc:10.22 % - Loss:2.302866695404053 %
# Model1 - Acc:10.42 % - Loss:2.302710386276245 %
# Model9 - Acc:9.54 % - Loss:2.3028258538246154 %
# Model6 - Acc:9.92 % - Loss:2.3029356756210326 %
# Model7 - Acc:10.0 % - Loss:2.302707329750061 %
# Model8 - Acc:10.52 % - Loss:2.3026813607215884 %
# Model0 - Acc:9.46 % - Loss:2.3027924251556398 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=11 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 12/30] ✓  time=48.93s  cumulative=565.91s
#   [Epoch 13/30] threads started …
# Agent 6 start
# Agent 7 start
# Agent 4 start
# Agent 5 start
# Agent 3 start
# Agent 8 start
# Agent 0 start
# Agent 1 start
# Agent 2 start
# Agent 9 start
# Model6 - Acc:9.28 % - Loss:2.302929425239563 %
# Model7 - Acc:9.96 % - Loss:2.3026802158355713 %
# Model4 - Acc:9.5 % - Loss:2.302715763092041 %
# Model5 - Acc:9.76 % - Loss:2.3028512444496156 %
# Model3 - Acc:9.26 % - Loss:2.302668951511383 %
# Model8 - Acc:10.82 % - Loss:2.302724913597107 %
# Model0 - Acc:9.58 % - Loss:2.3027866759300233 %
# Model2 - Acc:10.16 % - Loss:2.302621623039246 %
# Model1 - Acc:10.52 % - Loss:2.302709574699402 %
# Model9 - Acc:10.38 % - Loss:2.302749580383301 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=12 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 13/30] ✓  time=45.22s  cumulative=611.13s
#   [Epoch 14/30] threads started …
# Agent 1 start
# Agent 0 start
# Agent 7 start
# Agent 8 start
# Agent 6 start
# Agent 9 start
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 5 start
# Model1 - Acc:10.42 % - Loss:2.302722930431366 %
# Model0 - Acc:9.48 % - Loss:2.3028220171928404 %
# Model7 - Acc:9.92 % - Loss:2.30275652217865 %
# Model8 - Acc:10.4 % - Loss:2.302605634212494 %
# Model6 - Acc:9.54 % - Loss:2.3028912582397463 %
# Model9 - Acc:9.88 % - Loss:2.302819190502167 %
# Model3 - Acc:10.06 % - Loss:2.302688548088074 %
# Model4 - Acc:9.78 % - Loss:2.302693158149719 %
# Model2 - Acc:10.04 % - Loss:2.3026664080619814 %
# Model5 - Acc:9.9 % - Loss:2.302871295452118 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=13 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 14/30] ✓  time=43.09s  cumulative=654.22s
#   [Epoch 15/30] threads started …
# Agent 2 start
# Agent 3 start
# Agent 0 start
# Agent 8 start
# Agent 1 start
# Agent 9 start
# Agent 7 start
# Agent 5 start
# Agent 4 start
# Agent 6 start
# Model2 - Acc:9.66 % - Loss:2.302536478996277 %
# Model3 - Acc:9.86 % - Loss:2.3026571731567382 %
# Model0 - Acc:9.52 % - Loss:2.3027884731292723 %
# Model8 - Acc:10.56 % - Loss:2.3026648836135863 %
# Model1 - Acc:10.3 % - Loss:2.3026726713180543 %
# Model9 - Acc:9.88 % - Loss:2.3028009624481203 %
# Model7 - Acc:9.78 % - Loss:2.302796332836151 %
# Model5 - Acc:9.38 % - Loss:2.3028520193099977 %
# Model4 - Acc:9.68 % - Loss:2.302741829872131 %
# Model6 - Acc:9.46 % - Loss:2.3028585848808287 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=14 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 15/30] ✓  time=44.98s  cumulative=699.20s
#   [Epoch 16/30] threads started …
# Agent 3 start
# Agent 4 start
# Agent 5 start
# Agent 2 start
# Agent 9 start
# Agent 7 start
# Agent 6 start
# Agent 8 start
# Agent 0 start
# Agent 1 start
# Model3 - Acc:9.66 % - Loss:2.3026673674583433 %
# Model4 - Acc:9.12 % - Loss:2.302712903022766 %
# Model5 - Acc:10.36 % - Loss:2.302818409919739 %
# Model2 - Acc:10.02 % - Loss:2.3026220459938047 %
# Model9 - Acc:9.82 % - Loss:2.302807373046875 %
# Model7 - Acc:9.32 % - Loss:2.3027134990692137 %
# Model6 - Acc:9.68 % - Loss:2.3028750948905943 %
# Model8 - Acc:10.9 % - Loss:2.3026630973815916 %
# Model0 - Acc:9.5 % - Loss:2.3027463049888612 %
# Model1 - Acc:9.78 % - Loss:2.3027367143630983 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=15 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 16/30] ✓  time=43.87s  cumulative=743.07s
#   [Epoch 17/30] threads started …
# Agent 5 start
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Agent 2 start
# Agent 0 start
# Agent 9 start
# Agent 8 start
# Agent 3 start
# Agent 1 start
# Model5 - Acc:9.62 % - Loss:2.302845889568329 %
# Model6 - Acc:9.7 % - Loss:2.3029043459892273 %
# Model4 - Acc:9.9 % - Loss:2.3027195525169373 %
# Model7 - Acc:9.68 % - Loss:2.302653555393219 %
# Model2 - Acc:9.78 % - Loss:2.3026056079864503 %
# Model0 - Acc:9.56 % - Loss:2.302762822151184 %
# Model9 - Acc:9.66 % - Loss:2.302802574634552 %
# Model8 - Acc:10.54 % - Loss:2.3026841387748718 %
# Model3 - Acc:9.9 % - Loss:2.302652142047882 %
# Model1 - Acc:10.12 % - Loss:2.3027029128074648 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=16 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 17/30] ✓  time=42.53s  cumulative=785.61s
#   [Epoch 18/30] threads started …
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 9 start
# Agent 0 start
# Agent 2 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 3 start
# Model8 - Acc:10.48 % - Loss:2.302704505443573 %
# Model1 - Acc:10.74 % - Loss:2.3026906871795654 %
# Model7 - Acc:8.98 % - Loss:2.302687135696411 %
# Model9 - Acc:9.28 % - Loss:2.3028261036872864 %
# Model0 - Acc:9.84 % - Loss:2.3028134179115294 %
# Model2 - Acc:9.98 % - Loss:2.302601828098297 %
# Model6 - Acc:9.9 % - Loss:2.3028759117126465 %
# Model5 - Acc:9.24 % - Loss:2.3028502354621887 %
# Model4 - Acc:9.54 % - Loss:2.302693905353546 %
# Model3 - Acc:9.24 % - Loss:2.3026903195381165 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=17 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 18/30] ✓  time=42.79s  cumulative=828.40s
#   [Epoch 19/30] threads started …
# Agent 0 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 8 start
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 7 start
# Agent 6 start
# Model0 - Acc:9.42 % - Loss:2.302757830142975 %
# Model2 - Acc:9.98 % - Loss:2.302610070705414 %
# Model9 - Acc:9.86 % - Loss:2.302835048675537 %
# Model8 - Acc:10.72 % - Loss:2.302647678852081 %
# Model1 - Acc:10.36 % - Loss:2.3025975527763367 %
# Model5 - Acc:9.24 % - Loss:2.3028903498649598 %
# Model3 - Acc:10.42 % - Loss:2.302628083705902 %
# Model4 - Acc:9.98 % - Loss:2.3027533144950865 %
# Model7 - Acc:10.08 % - Loss:2.3026449551582338 %
# Model6 - Acc:9.5 % - Loss:2.3029065418243406 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=18 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 19/30] ✓  time=43.25s  cumulative=871.65s
#   [Epoch 20/30] threads started …
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 5 start
# Agent 1 start
# Agent 0 start
# Agent 7 start
# Agent 8 start
# Agent 9 start
# Agent 6 start
# Model3 - Acc:9.58 % - Loss:2.3026659355163575 %
# Model4 - Acc:9.54 % - Loss:2.302742615699768 %
# Model2 - Acc:10.3 % - Loss:2.3026665716171264 %
# Model5 - Acc:10.28 % - Loss:2.3028273854255676 %
# Model1 - Acc:10.22 % - Loss:2.3026656031608583 %
# Model0 - Acc:9.26 % - Loss:2.30281852722168 %
# Model7 - Acc:9.68 % - Loss:2.3027297558784485 %
# Model8 - Acc:10.74 % - Loss:2.3026703228950502 %
# Model9 - Acc:9.96 % - Loss:2.3027594623565673 %
# Model6 - Acc:9.1 % - Loss:2.302932945251465 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=19 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 20/30] ✓  time=43.25s  cumulative=914.90s
#   [Epoch 21/30] threads started …
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Agent 3 start
# Agent 7 start
# Agent 2 start
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Agent 9 start
# Model4 - Acc:9.98 % - Loss:2.302757968425751 %
# Model6 - Acc:9.64 % - Loss:2.3029043245315552 %
# Model5 - Acc:10.0 % - Loss:2.3028214812278747 %
# Model3 - Acc:9.72 % - Loss:2.3027011766433714 %
# Model7 - Acc:9.36 % - Loss:2.3027580671310424 %
# Model2 - Acc:10.12 % - Loss:2.30260328578949 %
# Model0 - Acc:9.4 % - Loss:2.3027452087402343 %
# Model1 - Acc:10.24 % - Loss:2.3026823949813844 %
# Model8 - Acc:10.84 % - Loss:2.302608929157257 %
# Model9 - Acc:10.12 % - Loss:2.3027609610557556 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=20 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 21/30] ✓  time=43.51s  cumulative=958.41s
#   [Epoch 22/30] threads started …
# Agent 7 start
# Agent 8 start
# Agent 5 start
# Agent 6 start
# Agent 0 start
# Agent 1 start
# Agent 2 start
# Agent 4 start
# Agent 9 start
# Agent 3 start
# Model7 - Acc:9.56 % - Loss:2.302782804489136 %
# Model8 - Acc:10.86 % - Loss:2.302674927711487 %
# Model5 - Acc:9.88 % - Loss:2.3028359746932985 %
# Model6 - Acc:9.32 % - Loss:2.302913447380066 %
# Model0 - Acc:9.02 % - Loss:2.3027489404678345 %
# Model1 - Acc:10.08 % - Loss:2.3027167167663576 %
# Model4 - Acc:9.86 % - Loss:2.302651786804199 %
# Model2 - Acc:10.22 % - Loss:2.302635171890259 %
# Model9 - Acc:10.16 % - Loss:2.3027989964485167 %
# Model3 - Acc:10.04 % - Loss:2.3026250820159913 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=21 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 22/30] ✓  time=42.24s  cumulative=1000.65s
#   [Epoch 23/30] threads started …
# Agent 2 start
# Agent 1 start
# Agent 9 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Agent 5 start
# Model2 - Acc:10.04 % - Loss:2.3026312685012815 %
# Model1 - Acc:10.54 % - Loss:2.3027220187187196 %
# Model9 - Acc:9.98 % - Loss:2.3028462052345278 %
# Model0 - Acc:9.38 % - Loss:2.3026989698410034 %
# Model8 - Acc:10.68 % - Loss:2.3027212023735046 %
# Model7 - Acc:9.74 % - Loss:2.3027214388847352 %
# Model3 - Acc:10.18 % - Loss:2.30265695476532 %
# Model6 - Acc:9.3 % - Loss:2.3029303340911866 %
# Model4 - Acc:9.9 % - Loss:2.3027595744132996 %
# Model5 - Acc:10.0 % - Loss:2.3028079171180726 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=22 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 23/30] ✓  time=43.12s  cumulative=1043.77s
#   [Epoch 24/30] threads started …
# Agent 1 start
# Agent 9 start
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 0 start
# Agent 8 start
# Agent 6 start
# Agent 7 start
# Agent 5 start
# Model1 - Acc:10.22 % - Loss:2.302749053478241 %
# Model3 - Acc:9.68 % - Loss:2.3026024360656736 %
# Model9 - Acc:9.9 % - Loss:2.3028107562065125 %
# Model4 - Acc:10.08 % - Loss:2.302699768066406 %
# Model2 - Acc:10.34 % - Loss:2.302707274913788 %
# Model0 - Acc:9.62 % - Loss:2.302731535434723 %
# Model8 - Acc:10.58 % - Loss:2.302745177745819 %
# Model6 - Acc:9.52 % - Loss:2.302940674304962 %
# Model7 - Acc:9.78 % - Loss:2.302733558177948 %
# Model5 - Acc:9.58 % - Loss:2.3028030076026917 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=23 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 24/30] ✓  time=39.49s  cumulative=1083.26s
#   [Epoch 25/30] threads started …
# Agent 4 start
# Agent 3 start
# Agent 6 start
# Agent 5 start
# Agent 1 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Agent 9 start
# Agent 2 start
# Model4 - Acc:10.44 % - Loss:2.302723942756653 %
# Model6 - Acc:9.72 % - Loss:2.302928969860077 %
# Model3 - Acc:10.0 % - Loss:2.3026514949798584 %
# Model5 - Acc:10.26 % - Loss:2.302826858997345 %
# Model1 - Acc:10.68 % - Loss:2.30269074344635 %
# Model0 - Acc:9.26 % - Loss:2.3028041429519654 %
# Model8 - Acc:10.4 % - Loss:2.3026462216377257 %
# Model7 - Acc:9.5 % - Loss:2.302710226535797 %
# Model9 - Acc:9.5 % - Loss:2.302772825717926 %
# Model2 - Acc:9.88 % - Loss:2.302672571182251 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=24 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 25/30] ✓  time=34.09s  cumulative=1117.35s
#   [Epoch 26/30] threads started …
# Agent 6 start
# Agent 0 start
# Agent 7 start
# Agent 8 start
# Agent 5 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 4 start
# Agent 3 start
# Model0 - Acc:9.38 % - Loss:2.302738280296326 %
# Model6 - Acc:9.7 % - Loss:2.302931842803955 %
# Model7 - Acc:10.18 % - Loss:2.302718170642853 %
# Model8 - Acc:10.6 % - Loss:2.3026593284606935 %
# Model2 - Acc:9.64 % - Loss:2.3026378602981565 %
# Model5 - Acc:9.86 % - Loss:2.302834125995636 %
# Model9 - Acc:10.44 % - Loss:2.3028540287017822 %
# Model1 - Acc:10.72 % - Loss:2.3026842741966247 %
# Model4 - Acc:9.68 % - Loss:2.3027942175865173 %
# Model3 - Acc:10.16 % - Loss:2.3026107301712035 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=25 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 26/30] ✓  time=34.17s  cumulative=1151.52s
#   [Epoch 27/30] threads started …
# Agent 2 start
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Agent 9 start
# Agent 5 start
# Agent 7 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Model2 - Acc:10.28 % - Loss:2.302650712966919 %
# Model0 - Acc:9.6 % - Loss:2.302751814842224 %
# Model1 - Acc:10.82 % - Loss:2.3026348843574524 %
# Model8 - Acc:10.6 % - Loss:2.3027240443229675 %
# Model9 - Acc:10.2 % - Loss:2.3028049993515016 %
# Model5 - Acc:9.82 % - Loss:2.3027940511703493 %
# Model3 - Acc:9.58 % - Loss:2.302644202709198 %
# Model6 - Acc:9.42 % - Loss:2.302886225223541 %
# Model4 - Acc:10.02 % - Loss:2.3027226934432985 %
# Model7 - Acc:9.86 % - Loss:2.3027628130912783 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=26 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 27/30] ✓  time=33.99s  cumulative=1185.51s
#   [Epoch 28/30] threads started …
# Agent 1 start
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 9 start
# Agent 6 start
# Agent 0 start
# Agent 5 start
# Agent 7 start
# Agent 8 start
# Model1 - Acc:10.54 % - Loss:2.302633535861969 %
# Model3 - Acc:10.0 % - Loss:2.3026929860115053 %
# Model2 - Acc:10.02 % - Loss:2.302608265399933 %
# Model4 - Acc:9.48 % - Loss:2.3027607522010802 %
# Model6 - Acc:9.66 % - Loss:2.3028654789924623 %
# Model9 - Acc:9.92 % - Loss:2.302867572784424 %
# Model0 - Acc:9.5 % - Loss:2.302736026763916 %
# Model5 - Acc:9.68 % - Loss:2.302796287059784 %
# Model7 - Acc:9.74 % - Loss:2.3026696400642397 %
# Model8 - Acc:10.84 % - Loss:2.3026480112075807 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=27 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 28/30] ✓  time=32.77s  cumulative=1218.28s
#   [Epoch 29/30] threads started …
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 0 start
# Agent 6 start
# Agent 1 start
# Agent 7 start
# Agent 9 start
# Agent 8 start
# Model3 - Acc:9.98 % - Loss:2.3026377234458923 %
# Model5 - Acc:9.52 % - Loss:2.302853297710419 %
# Model4 - Acc:9.72 % - Loss:2.3027452602386473 %
# Model0 - Acc:9.04 % - Loss:2.302767776489258 %
# Model6 - Acc:9.78 % - Loss:2.3029204063415527 %
# Model2 - Acc:10.34 % - Loss:2.3026352643966677 %
# Model1 - Acc:10.34 % - Loss:2.302709080696106 %
# Model7 - Acc:9.36 % - Loss:2.302756896972656 %
# Model9 - Acc:10.22 % - Loss:2.302838830947876 %
# Model8 - Acc:10.36 % - Loss:2.302673334121704 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=28 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 29/30] ✓  time=32.44s  cumulative=1250.72s
#   [Epoch 30/30] threads started …
# Agent 6 start
# Agent 7 start
# Agent 5 start
# Agent 4 start
# Agent 8 start
# Agent 1 start
# Agent 2 start
# Agent 0 start
# Agent 3 start
# Agent 9 start
# Model6 - Acc:9.68 % - Loss:2.302895037174225 %
# Model7 - Acc:9.64 % - Loss:2.3026940231323243 %
# Model5 - Acc:9.82 % - Loss:2.3028327870368956 %
# Model8 - Acc:10.7 % - Loss:2.3026899213790895 %
# Model1 - Acc:10.94 % - Loss:2.3026448922157288 %
# Model2 - Acc:9.82 % - Loss:2.3025523443222045 %
# Model0 - Acc:9.56 % - Loss:2.3027651467323302 %
# Model3 - Acc:10.1 % - Loss:2.302652171611786 %
# Model9 - Acc:9.44 % - Loss:2.3027604818344116 %
# Model4 - Acc:9.76 % - Loss:2.302735328197479 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=29 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 30/30] ✓  time=32.32s  cumulative=1283.05s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=30 | total=1283.05s | mean=42.77s/ep | fastest=ep30(32.32s) | slowest=ep1(54.47s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : CS_fully_connected_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 10.07%
#   Val Loss  finale : 2.3026
#   Temps total      : 1283.05s
#   Temps moyen/ép.  : 42.77s
#   Époque la + rapide : ép.30 (32.32s)
#   Époque la + lente  : ép.1 (54.47s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_fully_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 638.642 MB
#     Total messages    : 2,700
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 24.40 ms
#     Synchro totale    : 731.9 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_fully_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 638.642 MB
#     Total messages    : 2,700
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 24.40 ms
#     Synchro totale    : 731.9 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ============================================================
#   RUN — méthode : CS_cycle_graph)
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/30] threads started …
# Agent 7 start
# Agent 2 start
# Agent 9 start
# Agent 0 start
# Agent 1 start
# Agent 3 start
# Agent 8 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Model7 - Acc:11.54 % - Loss:2.3015686349868774 %
# Model2 - Acc:11.12 % - Loss:2.3001450786590576 %
# Model9 - Acc:11.58 % - Loss:2.3014781017303467 %
# Model0 - Acc:10.3 % - Loss:2.3017976026535036 %
# Model1 - Acc:10.08 % - Loss:2.3037110667228697 %
# Model3 - Acc:10.68 % - Loss:2.3002370228767397 %
# Model8 - Acc:10.64 % - Loss:2.303120207309723 %
# Model5 - Acc:10.48 % - Loss:2.302997143745422 %
# Model4 - Acc:12.92 % - Loss:2.296854726791382 %
# Model6 - Acc:11.86 % - Loss:2.2991785850524904 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=0 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 1/30] ✓  time=32.72s  cumulative=32.72s
#   [Epoch 2/30] threads started …
# Agent 2 start
# Agent 6 start
# Agent 3 start
# Agent 0 start
# Agent 9 start
# Agent 4 start
# Agent 1 start
# Agent 8 start
# Agent 7 start
# Agent 5 start
# Model2 - Acc:9.96 % - Loss:2.3030838375091554 %
# Model6 - Acc:10.42 % - Loss:2.302561140060425 %
# Model3 - Acc:10.9 % - Loss:2.3021964859962463 %
# Model9 - Acc:10.32 % - Loss:2.3030339007377623 %
# Model4 - Acc:10.84 % - Loss:2.3022249693870545 %
# Model1 - Acc:10.06 % - Loss:2.302911710739136 %
# Model7 - Acc:9.66 % - Loss:2.303131360054016 %
# Model0 - Acc:10.24 % - Loss:2.3024771132469177 %
# Model5 - Acc:10.38 % - Loss:2.3023603234291077 %
# Model8 - Acc:10.76 % - Loss:2.302412108898163 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=1 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 2/30] ✓  time=32.94s  cumulative=65.66s
#   [Epoch 3/30] threads started …
# Agent 2 start
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 1 start
# Agent 8 start
# Agent 6 start
# Agent 0 start
# Agent 9 start
# Agent 7 start
# Model2 - Acc:10.28 % - Loss:2.302632523536682 %
# Model5 - Acc:10.04 % - Loss:2.302569396495819 %
# Model3 - Acc:10.44 % - Loss:2.302137128353119 %
# Model4 - Acc:11.2 % - Loss:2.301633176803589 %
# Model1 - Acc:10.72 % - Loss:2.3026559324264526 %
# Model8 - Acc:10.48 % - Loss:2.302401252269745 %
# Model6 - Acc:9.94 % - Loss:2.302364354610443 %
# Model0 - Acc:9.8 % - Loss:2.302387042045593 %
# Model9 - Acc:9.96 % - Loss:2.302977903366089 %
# Model7 - Acc:9.5 % - Loss:2.303017535209656 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=2 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 3/30] ✓  time=32.27s  cumulative=97.93s
#   [Epoch 4/30] threads started …
# Agent 5 start
# Agent 7 start
# Agent 4 start
# Agent 6 start
# Agent 9 start
# Agent 3 start
# Agent 2 start
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Model5 - Acc:10.84 % - Loss:2.302608997821808 %
# Model7 - Acc:9.9 % - Loss:2.3030091938972475 %
# Model6 - Acc:10.16 % - Loss:2.3023055968284605 %
# Model4 - Acc:11.18 % - Loss:2.3017478756904604 %
# Model9 - Acc:10.36 % - Loss:2.3029060797691345 %
# Model3 - Acc:12.08 % - Loss:2.302144343852997 %
# Model2 - Acc:10.26 % - Loss:2.3025754327774046 %
# Model0 - Acc:9.74 % - Loss:2.3023609676361083 %
# Model1 - Acc:10.64 % - Loss:2.3026167793273924 %
# Model8 - Acc:10.42 % - Loss:2.3024418807029723 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=3 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 4/30] ✓  time=32.26s  cumulative=130.18s
#   [Epoch 5/30] threads started …
# Agent 7 start
# Agent 8 start
# Agent 9 start
# Agent 0 start
# Agent 6 start
# Agent 1 start
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Agent 5 start
# Model7 - Acc:10.1 % - Loss:2.3029213066101075 %
# Model8 - Acc:9.92 % - Loss:2.3024308366775514 %
# Model9 - Acc:10.04 % - Loss:2.3028579931259157 %
# Model0 - Acc:10.42 % - Loss:2.3023081483840944 %
# Model1 - Acc:10.72 % - Loss:2.302600766658783 %
# Model2 - Acc:10.14 % - Loss:2.3025162773132326 %
# Model4 - Acc:11.02 % - Loss:2.301737753868103 %
# Model5 - Acc:10.28 % - Loss:2.3025593585968016 %
# Model3 - Acc:11.52 % - Loss:2.302113164424896 %
# Model6 - Acc:10.06 % - Loss:2.3022308716773985 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=4 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 5/30] ✓  time=32.88s  cumulative=163.06s
#   [Epoch 6/30] threads started …
# Agent 3 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 0 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Agent 8 start
# Agent 7 start
# Model3 - Acc:10.94 % - Loss:2.3020809960365294 %
# Model2 - Acc:10.66 % - Loss:2.302495232582092 %
# Model9 - Acc:10.2 % - Loss:2.3029228434562685 %
# Model1 - Acc:10.72 % - Loss:2.3025614104270935 %
# Model4 - Acc:10.98 % - Loss:2.3017288136482237 %
# Model6 - Acc:10.12 % - Loss:2.3022130312919615 %
# Model5 - Acc:10.32 % - Loss:2.3025524497032164 %
# Model0 - Acc:10.58 % - Loss:2.3023493881225585 %
# Model7 - Acc:10.18 % - Loss:2.302951817512512 %
# Model8 - Acc:10.26 % - Loss:2.302451377391815 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=5 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 6/30] ✓  time=33.37s  cumulative=196.43s
#   [Epoch 7/30] threads started …
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 8 start
# Agent 0 start
# Agent 7 start
# Agent 9 start
# Agent 1 start
# Agent 6 start
# Model3 - Acc:11.4 % - Loss:2.3021183557510376 %
# Model5 - Acc:10.14 % - Loss:2.3026052989959718 %
# Model4 - Acc:10.96 % - Loss:2.3016708483695982 %
# Model8 - Acc:10.4 % - Loss:2.3023795833587646 %
# Model2 - Acc:10.66 % - Loss:2.3024306983947755 %
# Model0 - Acc:10.48 % - Loss:2.302340126514435 %
# Model7 - Acc:10.1 % - Loss:2.3029028968811036 %
# Model9 - Acc:10.06 % - Loss:2.302904939174652 %
# Model1 - Acc:10.72 % - Loss:2.302623025417328 %
# Model6 - Acc:10.36 % - Loss:2.3022367105484007 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=6 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 7/30] ✓  time=32.52s  cumulative=228.95s
#   [Epoch 8/30] threads started …
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 3 start
# Agent 8 start
# Agent 0 start
# Agent 1 start
# Agent 2 start
# Agent 9 start
# Model7 - Acc:10.34 % - Loss:2.3028942313194274 %
# Model6 - Acc:9.84 % - Loss:2.3021879229545594 %
# Model5 - Acc:10.92 % - Loss:2.302515238761902 %
# Model3 - Acc:10.74 % - Loss:2.3021268191337585 %
# Model8 - Acc:10.26 % - Loss:2.302445199012756 %
# Model0 - Acc:10.42 % - Loss:2.302390762805939 %
# Model4 - Acc:11.28 % - Loss:2.301619315624237 %
# Model1 - Acc:10.52 % - Loss:2.3026153826713562 %
# Model2 - Acc:10.34 % - Loss:2.3025031704902648 %
# Model9 - Acc:10.36 % - Loss:2.302902873039246 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=7 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 8/30] ✓  time=32.49s  cumulative=261.44s
#   [Epoch 9/30] threads started …
# Agent 9 start
# Agent 6 start
# Agent 7 start
# Agent 0 start
# Agent 3 start
# Agent 2 start
# Agent 8 start
# Agent 1 start
# Agent 5 start
# Agent 4 start
# Model9 - Acc:10.26 % - Loss:2.3029108638763427 %
# Model7 - Acc:10.02 % - Loss:2.3028498582839965 %
# Model6 - Acc:10.16 % - Loss:2.30220294046402 %
# Model3 - Acc:10.76 % - Loss:2.30207466506958 %
# Model0 - Acc:10.26 % - Loss:2.3023853487968444 %
# Model2 - Acc:10.66 % - Loss:2.3024227647781372 %
# Model1 - Acc:10.2 % - Loss:2.3025479402542115 %
# Model8 - Acc:10.1 % - Loss:2.3024093351364137 %
# Model5 - Acc:10.3 % - Loss:2.3024437494277956 %
# Model4 - Acc:11.24 % - Loss:2.3015831236839293 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=8 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 9/30] ✓  time=32.39s  cumulative=293.83s
#   [Epoch 10/30] threads started …
# Agent 1 start
# Agent 9 start
# Agent 8 start
# Agent 2 start
# Agent 7 start
# Agent 0 start
# Agent 3 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Model1 - Acc:10.72 % - Loss:2.302581404209137 %
# Model9 - Acc:9.9 % - Loss:2.3029084382057188 %
# Model2 - Acc:10.68 % - Loss:2.3024645986557006 %
# Model7 - Acc:9.76 % - Loss:2.3028468413352967 %
# Model8 - Acc:10.62 % - Loss:2.3024120054244994 %
# Model3 - Acc:11.62 % - Loss:2.3019858503341677 %
# Model4 - Acc:11.48 % - Loss:2.301490839958191 %
# Model6 - Acc:10.1 % - Loss:2.302185257911682 %
# Model0 - Acc:10.52 % - Loss:2.302374364852905 %
# Model5 - Acc:10.26 % - Loss:2.3024098019599917 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=9 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 10/30] ✓  time=33.53s  cumulative=327.36s
#   [Epoch 11/30] threads started …
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 0 start
# Agent 1 start
# Agent 7 start
# Agent 8 start
# Agent 6 start
# Agent 9 start
# Model3 - Acc:12.0 % - Loss:2.3018790259361266 %
# Model5 - Acc:10.98 % - Loss:2.302195146560669 %
# Model4 - Acc:11.78 % - Loss:2.301344701766968 %
# Model2 - Acc:10.22 % - Loss:2.302416215419769 %
# Model0 - Acc:9.96 % - Loss:2.302379276752472 %
# Model1 - Acc:10.56 % - Loss:2.302558732032776 %
# Model7 - Acc:10.08 % - Loss:2.3028080248832703 %
# Model8 - Acc:10.48 % - Loss:2.3024335646629335 %
# Model6 - Acc:10.5 % - Loss:2.3021007275581358 %
# Model9 - Acc:9.56 % - Loss:2.302911835193634 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=10 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 11/30] ✓  time=32.08s  cumulative=359.43s
#   [Epoch 12/30] threads started …
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 9 start
# Agent 3 start
# Agent 0 start
# Agent 2 start
# Agent 1 start
# Agent 8 start
# Model7 - Acc:10.34 % - Loss:2.302788362979889 %
# Model6 - Acc:10.76 % - Loss:2.3020313744544985 %
# Model5 - Acc:11.18 % - Loss:2.301933680057526 %
# Model9 - Acc:10.18 % - Loss:2.3028465871810915 %
# Model4 - Acc:12.38 % - Loss:2.301074399471283 %
# Model0 - Acc:10.16 % - Loss:2.3023282265663148 %
# Model3 - Acc:10.64 % - Loss:2.3015535597801207 %
# Model2 - Acc:10.84 % - Loss:2.302315988063812 %
# Model1 - Acc:10.72 % - Loss:2.302504367828369 %
# Model8 - Acc:9.94 % - Loss:2.302441559791565 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=11 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 12/30] ✓  time=32.17s  cumulative=391.61s
#   [Epoch 13/30] threads started …
# Agent 6 start
# Agent 7 start
# Agent 1 start
# Agent 9 start
# Agent 8 start
# Agent 0 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Model7 - Acc:10.22 % - Loss:2.3027413454055785 %
# Model6 - Acc:10.46 % - Loss:2.3018841977119444 %
# Model1 - Acc:10.36 % - Loss:2.3025372591018676 %
# Model9 - Acc:10.28 % - Loss:2.3028885254859923 %
# Model8 - Acc:10.62 % - Loss:2.302457972049713 %
# Model0 - Acc:10.1 % - Loss:2.302349022388458 %
# Model5 - Acc:11.14 % - Loss:2.3013946242332457 %
# Model4 - Acc:13.52 % - Loss:2.3004063687324523 %
# Model3 - Acc:10.64 % - Loss:2.301298680782318 %
# Model2 - Acc:10.68 % - Loss:2.30221351480484 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=12 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 13/30] ✓  time=32.78s  cumulative=424.39s
#   [Epoch 14/30] threads started …
# Agent 8 start
# Agent 9 start
# Agent 2 start
# Agent 0 start
# Agent 3 start
# Agent 1 start
# Agent 6 start
# Agent 7 start
# Agent 4 start
# Agent 5 start
# Model8 - Acc:10.34 % - Loss:2.3024127502441405 %
# Model9 - Acc:9.42 % - Loss:2.302875998020172 %
# Model2 - Acc:10.72 % - Loss:2.302021812915802 %
# Model3 - Acc:12.04 % - Loss:2.300399200439453 %
# Model1 - Acc:10.3 % - Loss:2.30252832365036 %
# Model6 - Acc:10.86 % - Loss:2.3015141167640687 %
# Model0 - Acc:10.08 % - Loss:2.302349370479584 %
# Model7 - Acc:9.98 % - Loss:2.3027009100914 %
# Model4 - Acc:14.42 % - Loss:2.2989515595436094 %
# Model5 - Acc:10.94 % - Loss:2.3002035846710207 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=13 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 14/30] ✓  time=32.89s  cumulative=457.28s
#   [Epoch 15/30] threads started …
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 6 start
# Agent 0 start
# Agent 8 start
# Agent 9 start
# Agent 1 start
# Agent 7 start
# Model3 - Acc:14.08 % - Loss:2.2974687061309815 %
# Model5 - Acc:11.96 % - Loss:2.2949908504486083 %
# Model4 - Acc:15.52 % - Loss:2.292401708126068 %
# Model6 - Acc:12.62 % - Loss:2.300472230434418 %
# Model0 - Acc:10.48 % - Loss:2.302389126300812 %
# Model2 - Acc:11.4 % - Loss:2.301609323978424 %
# Model8 - Acc:10.18 % - Loss:2.302461654663086 %
# Model9 - Acc:10.36 % - Loss:2.3028129835128786 %
# Model1 - Acc:10.56 % - Loss:2.3024979257583618 %
# Model7 - Acc:10.34 % - Loss:2.302570093154907 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=14 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 15/30] ✓  time=32.13s  cumulative=489.41s
#   [Epoch 16/30] threads started …
# Agent 5 start
# Agent 7 start
# Agent 6 start
# Agent 4 start
# Agent 3 start
# Agent 0 start
# Agent 8 start
# Agent 9 start
# Agent 2 start
# Agent 1 start
# Model5 - Acc:13.96 % - Loss:2.2570411744117735 %
# Model7 - Acc:10.28 % - Loss:2.3021337575912475 %
# Model6 - Acc:11.46 % - Loss:2.2920269289016724 %
# Model3 - Acc:15.2 % - Loss:2.2671833641529084 %
# Model0 - Acc:10.2 % - Loss:2.3024123139381407 %
# Model4 - Acc:15.42 % - Loss:2.2545885789394378 %
# Model8 - Acc:10.54 % - Loss:2.3023139572143556 %
# Model2 - Acc:10.72 % - Loss:2.299769603252411 %
# Model9 - Acc:9.3 % - Loss:2.302850157737732 %
# Model1 - Acc:10.58 % - Loss:2.3023141198158266 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=15 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 16/30] ✓  time=33.47s  cumulative=522.88s
#   [Epoch 17/30] threads started …
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Agent 5 start
# Agent 7 start
# Agent 9 start
# Agent 3 start
# Agent 6 start
# Agent 2 start
# Agent 4 start
# Model0 - Acc:10.18 % - Loss:2.3021994709968565 %
# Model1 - Acc:10.72 % - Loss:2.3014799156188963 %
# Model8 - Acc:10.04 % - Loss:2.3021838026046755 %
# Model5 - Acc:17.54 % - Loss:2.1910804677009583 %
# Model7 - Acc:12.06 % - Loss:2.2973963074684143 %
# Model9 - Acc:10.16 % - Loss:2.302778592586517 %
# Model3 - Acc:17.28 % - Loss:2.204351954936981 %
# Model2 - Acc:15.42 % - Loss:2.267663709640503 %
# Model4 - Acc:17.4 % - Loss:2.1924729030132295 %
# Model6 - Acc:14.84 % - Loss:2.232254964828491 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=16 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 17/30] ✓  time=33.97s  cumulative=556.85s
#   [Epoch 18/30] threads started …
# Agent 9 start
# Agent 8 start
# Agent 1 start
# Agent 2 start
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 0 start
# Agent 3 start
# Model9 - Acc:10.02 % - Loss:2.302692277431488 %
# Model1 - Acc:12.56 % - Loss:2.2759513432979586 %
# Model2 - Acc:17.8 % - Loss:2.205060837030411 %
# Model8 - Acc:12.04 % - Loss:2.300781183719635 %
# Model7 - Acc:16.12 % - Loss:2.243457235097885 %
# Model6 - Acc:18.92 % - Loss:2.167318870306015 %
# Model4 - Acc:18.98 % - Loss:2.150317063808441 %
# Model5 - Acc:18.58 % - Loss:2.1400803360939027 %
# Model3 - Acc:18.5 % - Loss:2.1535771536827086 %
# Model0 - Acc:10.58 % - Loss:2.3019500346183777 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=17 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 18/30] ✓  time=34.36s  cumulative=591.20s
#   [Epoch 19/30] threads started …
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 5 start
# Agent 7 start
# Agent 6 start
# Agent 9 start
# Agent 0 start
# Agent 8 start
# Agent 1 start
# Model3 - Acc:19.86 % - Loss:2.125506920814514 %
# Model4 - Acc:19.06 % - Loss:2.1259730541706086 %
# Model5 - Acc:19.18 % - Loss:2.119245761156082 %
# Model2 - Acc:18.48 % - Loss:2.161450744152069 %
# Model7 - Acc:18.32 % - Loss:2.1839079315662384 %
# Model6 - Acc:19.66 % - Loss:2.1309339945316315 %
# Model9 - Acc:12.32 % - Loss:2.3017549810409546 %
# Model0 - Acc:13.82 % - Loss:2.2843796210289002 %
# Model8 - Acc:16.12 % - Loss:2.2597987179756163 %
# Model1 - Acc:18.08 % - Loss:2.199459686279297 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=18 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 19/30] ✓  time=32.40s  cumulative=623.60s
#   [Epoch 20/30] threads started …
# Agent 5 start
# Agent 4 start
# Agent 6 start
# Agent 7 start
# Agent 8 start
# Agent 0 start
# Agent 1 start
# Agent 2 start
# Agent 3 start
# Agent 9 start
# Model5 - Acc:19.42 % - Loss:2.0982042963504792 %
# Model6 - Acc:19.84 % - Loss:2.1096031889915468 %
# Model4 - Acc:19.38 % - Loss:2.1055600843429567 %
# Model7 - Acc:18.78 % - Loss:2.148729278802872 %
# Model8 - Acc:17.48 % - Loss:2.1852705335617064 %
# Model0 - Acc:17.16 % - Loss:2.203952382326126 %
# Model1 - Acc:18.96 % - Loss:2.1548295738697054 %
# Model2 - Acc:18.6 % - Loss:2.134132007360458 %
# Model3 - Acc:19.84 % - Loss:2.105194990158081 %
# Model9 - Acc:16.18 % - Loss:2.22285949754715 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=19 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 20/30] ✓  time=33.55s  cumulative=657.16s
#   [Epoch 21/30] threads started …
# Agent 0 start
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 3 start
# Agent 6 start
# Agent 9 start
# Agent 2 start
# Agent 5 start
# Agent 4 start
# Model8 - Acc:18.6 % - Loss:2.1344477844238283 %
# Model0 - Acc:18.74 % - Loss:2.1442769417762757 %
# Model1 - Acc:18.94 % - Loss:2.124877484321594 %
# Model7 - Acc:18.94 % - Loss:2.125093159675598 %
# ...
# Agent 5 start
# Agent 3 start
# Agent 1 start
# Agent 2 start
# Agent 8 start
# Agent 7 start
# Agent 9 start
# Agent 6 start
# Agent 0 start
# Model4 - Acc:17.7 % - Loss:2.1797103152275086 %
# Model5 - Acc:17.46 % - Loss:2.1785504746437074 %
# Model3 - Acc:18.24 % - Loss:2.1823364834785464 %
# Model2 - Acc:17.9 % - Loss:2.192739636182785 %
# Model1 - Acc:18.44 % - Loss:2.1728159182071685 %
# Model8 - Acc:18.34 % - Loss:2.168907239675522 %
# Model7 - Acc:18.24 % - Loss:2.1889480063915254 %
# Model9 - Acc:19.1 % - Loss:2.1760490741729734 %
# Model6 - Acc:18.94 % - Loss:2.170566519021988 %
# Model0 - Acc:19.0 % - Loss:2.1642113461494445 %
# [DEBUG] set_epoch_messages called → 30 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 30
# [DEBUG] _record epoch=22 → n_messages=30
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 30
#   [Epoch 23/30] ✓  time=56.99s  cumulative=1288.22s
#   [Epoch 24/30] threads started …
# Agent 7 start
# Agent 6 start
# Agent 4 start
# Agent 5 start
# Agent 2 start
# Agent 0 start
# Agent 8 start
# Agent 3 start
# Agent 9 start
# Agent 1 start
# Model7 - Acc:19.0 % - Loss:2.145107429265976 %
# Model6 - Acc:19.54 % - Loss:2.1263395402431486 %
# Model4 - Acc:18.02 % - Loss:2.1335682907104494 %
# Model5 - Acc:19.0 % - Loss:2.138246747970581 %
# Model2 - Acc:18.56 % - Loss:2.14648505115509 %
# Model0 - Acc:19.68 % - Loss:2.1207130029201506 %
# Model8 - Acc:19.06 % - Loss:2.1291846215724943 %
# Model3 - Acc:19.36 % - Loss:2.137138603448868 %
# Model9 - Acc:19.52 % - Loss:2.1372558715343475 %
# Model1 - Acc:18.94 % - Loss:2.130589948415756 %
# [DEBUG] set_epoch_messages called → 22 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
# [DEBUG] _record epoch=23 → n_messages=22
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
#   [Epoch 24/30] ✓  time=54.55s  cumulative=1342.77s
#   [Epoch 25/30] threads started …
# Agent 1 start
# Agent 7 start
# Agent 8 start
# Agent 6 start
# Agent 0 start
# Agent 9 start
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Model1 - Acc:19.78 % - Loss:2.1009539806842805 %
# Model7 - Acc:18.44 % - Loss:2.117252202749252 %
# Model8 - Acc:19.34 % - Loss:2.1012401897907256 %
# Model6 - Acc:20.6 % - Loss:2.0995160512924196 %
# Model0 - Acc:19.84 % - Loss:2.0971702077388765 %
# Model9 - Acc:20.26 % - Loss:2.1106653797626493 %
# Model5 - Acc:18.96 % - Loss:2.113035853147507 %
# Model3 - Acc:19.26 % - Loss:2.1095494372844694 %
# Model4 - Acc:18.62 % - Loss:2.1046568262577057 %
# Model2 - Acc:18.76 % - Loss:2.121645487308502 %
# [DEBUG] set_epoch_messages called → 32 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 32
# [DEBUG] _record epoch=24 → n_messages=32
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 32
#   [Epoch 25/30] ✓  time=56.09s  cumulative=1398.86s
#   [Epoch 26/30] threads started …
# Agent 8 start
# Agent 4 start
# Agent 2 start
# Agent 9 start
# Agent 0 start
# Agent 5 start
# Agent 3 start
# Agent 1 start
# Agent 7 start
# Agent 6 start
# Model8 - Acc:19.04 % - Loss:2.0735085287094117 %
# Model2 - Acc:19.74 % - Loss:2.0949116492271425 %
# Model9 - Acc:20.32 % - Loss:2.0846143329143523 %
# Model0 - Acc:20.14 % - Loss:2.067585691690445 %
# Model4 - Acc:19.12 % - Loss:2.0785807106494905 %
# Model3 - Acc:20.22 % - Loss:2.080447156190872 %
# Model1 - Acc:20.04 % - Loss:2.074327533483505 %
# Model5 - Acc:19.38 % - Loss:2.085281189918518 %
# Model7 - Acc:19.6 % - Loss:2.089953539609909 %
# Model6 - Acc:20.3 % - Loss:2.068898078203201 %
# [DEBUG] set_epoch_messages called → 22 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
# [DEBUG] _record epoch=25 → n_messages=22
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
#   [Epoch 26/30] ✓  time=58.80s  cumulative=1457.65s
#   [Epoch 27/30] threads started …
# Agent 4 start
# Agent 2 start
# Agent 5 start
# Agent 3 start
# Agent 8 start
# Agent 9 start
# Agent 1 start
# Agent 6 start
# Agent 7 start
# Agent 0 start
# Model4 - Acc:19.48 % - Loss:2.0454788863658906 %
# Model2 - Acc:19.62 % - Loss:2.0602836925983428 %
# Model5 - Acc:20.08 % - Loss:2.050377069473267 %
# Model3 - Acc:20.4 % - Loss:2.0453283615112303 %
# Model8 - Acc:20.0 % - Loss:2.0389588255882263 %
# Model9 - Acc:20.06 % - Loss:2.051974370479584 %
# Model1 - Acc:19.66 % - Loss:2.043064496040344 %
# Model6 - Acc:20.8 % - Loss:2.0286188333034514 %
# Model7 - Acc:19.74 % - Loss:2.0547055289745333 %
# Model0 - Acc:21.02 % - Loss:2.0364760887622833 %
# [DEBUG] set_epoch_messages called → 22 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
# [DEBUG] _record epoch=26 → n_messages=22
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
#   [Epoch 27/30] ✓  time=60.48s  cumulative=1518.13s
#   [Epoch 28/30] threads started …
# Agent 5 start
# Agent 6 start
# Agent 2 start
# Agent 4 start
# Agent 7 start
# Agent 0 start
# Model5 - Acc:21.12 % - Loss:2.0039934232234953 %
# Agent 8 start
# Agent 3 start
# Agent 1 start
# Agent 9 start
# Model6 - Acc:21.96 % - Loss:1.98407861161232 %
# Model4 - Acc:20.1 % - Loss:2.005350209236145 %
# Model7 - Acc:21.14 % - Loss:2.011480337381363 %
# Model2 - Acc:20.72 % - Loss:2.0142682790756226 %
# Model0 - Acc:22.48 % - Loss:1.9814452776908875 %
# Model8 - Acc:21.04 % - Loss:1.9944647748470306 %
# Model3 - Acc:21.9 % - Loss:1.9970952928066255 %
# Model1 - Acc:20.62 % - Loss:1.9957283778190613 %
# Model9 - Acc:20.76 % - Loss:2.005029670238495 %
# [DEBUG] set_epoch_messages called → 14 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 14
# [DEBUG] _record epoch=27 → n_messages=14
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 14
#   [Epoch 28/30] ✓  time=63.79s  cumulative=1581.93s
#   [Epoch 29/30] threads started …
# Agent 3 start
# Agent 1 start
# Agent 9 start
# Agent 0 start
# Agent 8 start
# Agent 6 start
# Agent 5 start
# Agent 2 start
# Model1 - Acc:22.8 % - Loss:1.954310579776764 %
# Agent 7 start
# Agent 4 start
# Model3 - Acc:22.82 % - Loss:1.9541761059761047 %
# Model9 - Acc:21.72 % - Loss:1.9597678978443145 %
# Model0 - Acc:24.1 % - Loss:1.9343700339794159 %
# Model8 - Acc:22.48 % - Loss:1.950231243133545 %
# Model6 - Acc:22.56 % - Loss:1.9547472815513611 %
# Model7 - Acc:22.22 % - Loss:1.9676581280231475 %
# Model5 - Acc:22.98 % - Loss:1.961184849023819 %
# Model2 - Acc:22.62 % - Loss:1.9701259133815765 %
# Model4 - Acc:21.66 % - Loss:1.9606141943931579 %
# [DEBUG] set_epoch_messages called → 46 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 46
# [DEBUG] _record epoch=28 → n_messages=46
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 46
#   [Epoch 29/30] ✓  time=81.49s  cumulative=1663.42s
#   [Epoch 30/30] threads started …
# Agent 1 start
# Agent 2 start
# Agent 3 start
# Agent 8 start
# Agent 0 start
# Agent 9 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 7 start
# Model1 - Acc:23.2 % - Loss:1.920852826833725 %
# Model2 - Acc:23.26 % - Loss:1.9415154101848602 %
# Model3 - Acc:23.22 % - Loss:1.9268963570594788 %
# Model0 - Acc:24.22 % - Loss:1.9052705097198486 %
# Model8 - Acc:23.36 % - Loss:1.9190285308361053 %
# Model9 - Acc:22.62 % - Loss:1.9271813170909882 %
# Model6 - Acc:23.2 % - Loss:1.921122183561325 %
# Model5 - Acc:24.24 % - Loss:1.9328382346630097 %
# Model4 - Acc:22.54 % - Loss:1.928777954339981 %
# Model7 - Acc:22.24 % - Loss:1.9401490542888642 %
# [DEBUG] set_epoch_messages called → 26 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 26
# [DEBUG] _record epoch=29 → n_messages=26
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 26
#   [Epoch 30/30] ✓  time=68.79s  cumulative=1732.21s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=30 | total=1732.21s | mean=57.74s/ep | fastest=ep21(52.26s) | slowest=ep29(81.49s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : CS_random_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 24.55%
#   Val Loss  finale : 1.9186
#   Temps total      : 1732.21s
#   Temps moyen/ép.  : 57.74s
#   Époque la + rapide : ép.21 (52.26s)
#   Époque la + lente  : ép.29 (81.49s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 193.958 MB
#     Total messages    : 820
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 35.74 ms
#     Synchro totale    : 1072.1 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 193.958 MB
#     Total messages    : 820
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 35.74 ms
#     Synchro totale    : 1072.1 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════
#   CLASSEMENT FINAL — comparator.rank()
# ════════════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════════════════
#   CLASSEMENT DES MÉTHODES PAR EFFICACITÉ (accuracy / MB)
# ──────────────────────────────────────────────────────────────────────
#   Rang  Méthode                   Total MB     Synchro moy    Efficacité
# ──────────────────────────────────────────────────────────────────────
#   1     CS_fully_connected_graph  638.642      24.40          N/A
#   2     CS_cycle_graph)           141.920      10.85          N/A
#   3     CS_star_graph             127.728      22.17          N/A
#   4     CS_random_graph           193.958      35.74          N/A
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Méthode                          Val Loss    Val Acc  Train Acc
# ======================================================================
# CS_fully_connected_graph           2.3026     10.07%      9.56%
# CS_cycle_graph)                    1.8281     29.26%     28.12%
# CS_star_graph                      1.4855     44.36%     44.42%
# CS_random_graph                    1.9186     24.55%     24.22%
# ======================================================================
#
# ══════════════════════════════════════════════════════════════════════
#   CLASSEMENT DES MÉTHODES PAR EFFICACITÉ (accuracy / MB)
# ──────────────────────────────────────────────────────────────────────
#   Rang  Méthode                   Total MB     Synchro moy    Efficacité
# ──────────────────────────────────────────────────────────────────────
#   1     CS_fully_connected_graph  638.642      24.40          N/A
#   2     CS_cycle_graph)           141.920      10.85          N/A
#   3     CS_star_graph             127.728      22.17          N/A
#   4     CS_random_graph           193.958      35.74          N/A
# ══════════════════════════════════════════════════════════════════════
# ═══════════════════════════════════════════════════════
#   RunResult : CS_fully_connected_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 10.07%
#   Val Loss  finale : 2.3026
#   Temps total      : 1283.05s
#   Temps moyen/ép.  : 42.77s
#   Époque la + rapide : ép.30 (32.32s)
#   Époque la + lente  : ép.1 (54.47s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_fully_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 638.642 MB
#     Total messages    : 2,700
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 24.40 ms
#     Synchro totale    : 731.9 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : CS_cycle_graph)
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 29.26%
#   Val Loss  finale : 1.8281
#   Temps total      : 990.05s
#   Temps moyen/ép.  : 33.00s
#   Époque la + rapide : ép.11 (32.08s)
#   Époque la + lente  : ép.18 (34.36s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_cycle_graph)
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 141.920 MB
#     Total messages    : 600
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 10.85 ms
#     Synchro totale    : 325.4 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : CS_star_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 44.36%
#   Val Loss  finale : 1.4855
#   Temps total      : 1473.05s
#   Temps moyen/ép.  : 49.10s
#   Époque la + rapide : ép.6 (33.05s)
#   Époque la + lente  : ép.27 (67.58s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_star_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 127.728 MB
#     Total messages    : 540
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 22.17 ms
#     Synchro totale    : 665.2 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : CS_random_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 24.55%
#   Val Loss  finale : 1.9186
#   Temps total      : 1732.21s
#   Temps moyen/ép.  : 57.74s
#   Époque la + rapide : ép.21 (52.26s)
#   Époque la + lente  : ép.29 (81.49s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — CS_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 193.958 MB
#     Total messages    : 820
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 35.74 ms
#     Synchro totale    : 1072.1 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════

# %%
comparator.rank()

# %%
plot_cumulative_times(results)

# %%
plot_epoch_times(results)

# %%
comparator.plot_comparison()

# %%
for result in results:
    print(f"\n── {result.method_name} ──")
    result.comm_cost.summary()

# %%
print_benchmark_summary(results)

# %%
plot_all_benchmark_metrics(results)

# %%
plot_average_distance(results)

# %%
for result in results:
    print(result)
    result.comm_cost.summary()
    plot_cosine_similarity(result)
    plot_distance_heatmap(result.agent_list, result.method_name)
    plot_all_agent_node_weight_metric(result.agent_list)

    result.metrics.plot_history()

# %%
def Average_consensus_fully_connected_graph_k(agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.fully_connected_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


def Average_consensus_cycle_graph_k(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.cycle_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


def Average_consensus_star_graph_k(agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.star_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


def Average_consensus_random_graph_k(agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.random_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


# ──────────────────────────────────────────────────────────────
# Dictionnaire des méthodes à comparer
# ──────────────────────────────────────────────────────────────

COMMUNICATION_METHODS = {

    "AC_fully_connected_graph":
        Average_consensus_fully_connected_graph_k,

    "AC_cycle_graph":
        Average_consensus_cycle_graph_k,

    "AC_star_graph":
        Average_consensus_star_graph_k,

    "AC_random_graph":
        Average_consensus_random_graph_k,
}


# Device configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_list = generate_agent(BATCH_SIZE, N_AGENT, DEVICE)

results, comparator = benchmark_sequential(
    communication_methods=COMMUNICATION_METHODS,
    num_epochs=NUM_EPOCHES,
    graph=none,
    k=k,
    BATCH_SIZE=BATCH_SIZE,
    N_AGENT=N_AGENT,
    DEVICE=DEVICE,
)

print_benchmark_summary(results)
comparator.rank()
plot_all_benchmark_metrics(results)
plot_average_distance(results)
plot_cumulative_times(results)
plot_epoch_times(results)

for result in results:
    print(result)
    plot_cosine_similarity(result)
    plot_distance_heatmap(result.agent_list, result.method_name)
    plot_all_agent_node_weight_metric(result.agent_list)

    result.metrics.plot_history()
    result.comm_cost.summary()
# Out:
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#
# ============================================================
#   RUN — méthode : AC_fully_connected_graph
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/30] threads started …
# Agent 0 start
# Agent 6 start
# Agent 1 start
# Agent 8 start
# Agent 7 start
# Agent 9 start
# Agent 5 start
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Model0 - Acc:10.0 % - Loss:2.302659502029419 %
# Model6 - Acc:9.88 % - Loss:2.301495111942291 %
# Model1 - Acc:10.28 % - Loss:2.301960517883301 %
# Model8 - Acc:11.12 % - Loss:2.300993888378143 %
# Model7 - Acc:12.48 % - Loss:2.301524531364441 %
# Model9 - Acc:10.74 % - Loss:2.3023708443641664 %
# Model5 - Acc:10.24 % - Loss:2.3012474184036256 %
# Model2 - Acc:10.84 % - Loss:2.302871616363525 %
# Model4 - Acc:9.88 % - Loss:2.301652771949768 %
# Model3 - Acc:10.76 % - Loss:2.299858428478241 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=0 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 1/30] ✓  time=49.19s  cumulative=49.19s
#   [Epoch 2/30] threads started …
# Agent 7 start
# Agent 2 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 8 start
# Agent 4 start
# Agent 6 start
# Agent 3 start
# Agent 5 start
# Model7 - Acc:9.16 % - Loss:2.3030184350013734 %
# Model2 - Acc:9.98 % - Loss:2.3029147787094115 %
# Model1 - Acc:10.1 % - Loss:2.3027513728141784 %
# Model0 - Acc:10.34 % - Loss:2.3028122725486755 %
# Model9 - Acc:9.62 % - Loss:2.3029969458580015 %
# Model8 - Acc:10.5 % - Loss:2.3027510781288147 %
# Model4 - Acc:10.18 % - Loss:2.3027772321701048 %
# Model6 - Acc:10.02 % - Loss:2.3025310530662537 %
# Model3 - Acc:10.04 % - Loss:2.302770690917969 %
# Model5 - Acc:9.6 % - Loss:2.302886655330658 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=1 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 2/30] ✓  time=53.54s  cumulative=102.73s
#   [Epoch 3/30] threads started …
# Agent 3 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 4 start
# Agent 8 start
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Model3 - Acc:10.58 % - Loss:2.302768893241882 %
# Model2 - Acc:9.88 % - Loss:2.3027834300994874 %
# Model9 - Acc:9.68 % - Loss:2.3029314079284666 %
# Model1 - Acc:10.16 % - Loss:2.302712582588196 %
# Model4 - Acc:10.1 % - Loss:2.3027800784111023 %
# Model8 - Acc:10.72 % - Loss:2.3026396555900575 %
# Model0 - Acc:10.08 % - Loss:2.302751096725464 %
# Model7 - Acc:9.68 % - Loss:2.303019296169281 %
# Model6 - Acc:10.22 % - Loss:2.3025691862106323 %
# Model5 - Acc:9.64 % - Loss:2.3027796511650087 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=2 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 3/30] ✓  time=57.53s  cumulative=160.26s
#   [Epoch 4/30] threads started …
# Erreur agent 8 : [Errno 22] Invalid argument
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 6 start
# Agent 9 start
# Agent 7 start
# Agent 2 start
# Agent 0 start
# Agent 1 start
# Model5 - Acc:9.72 % - Loss:2.302771809577942 %
# Model3 - Acc:9.92 % - Loss:2.302717263698578 %
# Model4 - Acc:9.96 % - Loss:2.302769666671753 %
# Model6 - Acc:10.06 % - Loss:2.3025361638069155 %
# Model9 - Acc:9.92 % - Loss:2.3029292106628416 %
# Model7 - Acc:10.08 % - Loss:2.3029066100120543 %
# Model2 - Acc:9.24 % - Loss:2.302893114566803 %
# Model0 - Acc:10.2 % - Loss:2.3027381110191345 %
# Model1 - Acc:10.46 % - Loss:2.3026316180229185 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=3 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 4/30] ✓  time=46.72s  cumulative=206.99s
#   [Epoch 5/30] threads started …
# Agent 0 start
# Agent 2 start
# Agent 8 start
# Agent 1 start
# Agent 4 start
# Agent 9 start
# Agent 6 start
# Agent 7 start
# Agent 3 start
# Agent 5 start
# Model0 - Acc:9.78 % - Loss:2.30269126033783 %
# Model2 - Acc:9.76 % - Loss:2.3027858328819275 %
# Model8 - Acc:10.54 % - Loss:2.3027622990608214 %
# Model4 - Acc:9.76 % - Loss:2.302783212184906 %
# Model1 - Acc:9.76 % - Loss:2.302765356063843 %
# Model6 - Acc:9.94 % - Loss:2.30256662607193 %
# Model9 - Acc:9.56 % - Loss:2.3029106240272523 %
# Model7 - Acc:9.86 % - Loss:2.302921074390411 %
# Model3 - Acc:9.86 % - Loss:2.3026962532997133 %
# Model5 - Acc:9.44 % - Loss:2.3027527017593385 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=4 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 5/30] ✓  time=60.10s  cumulative=267.09s
#   [Epoch 6/30] threads started …
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Agent 3 start
# Agent 2 start
# Agent 5 start
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Agent 8 start
# Model4 - Acc:9.46 % - Loss:2.3027624559402464 %
# Model1 - Acc:10.26 % - Loss:2.3027063097953797 %
# Model9 - Acc:9.6 % - Loss:2.302896810531616 %
# Model3 - Acc:10.04 % - Loss:2.302682735443115 %
# Model2 - Acc:9.56 % - Loss:2.3028676681518556 %
# Model5 - Acc:9.84 % - Loss:2.3027639102935793 %
# Model0 - Acc:9.5 % - Loss:2.302677707195282 %
# Model7 - Acc:9.28 % - Loss:2.3029126982688903 %
# Model6 - Acc:10.16 % - Loss:2.3025291018486023 %
# Model8 - Acc:10.22 % - Loss:2.3027964429855348 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=5 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 6/30] ✓  time=62.78s  cumulative=329.87s
#   [Epoch 7/30] threads started …
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 3 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 7 start
# Agent 8 start
# Agent 2 start
# Model6 - Acc:10.02 % - Loss:2.3025010352134703 %
# Model5 - Acc:9.88 % - Loss:2.302773070812225 %
# Model4 - Acc:10.04 % - Loss:2.302801326751709 %
# Model3 - Acc:9.82 % - Loss:2.3027914061546326 %
# Model1 - Acc:10.3 % - Loss:2.3026664786338804 %
# Model0 - Acc:10.24 % - Loss:2.302699197292328 %
# Model9 - Acc:8.86 % - Loss:2.302936315536499 %
# Model7 - Acc:9.56 % - Loss:2.3029076924324037 %
# Model8 - Acc:10.28 % - Loss:2.3026939387321472 %
# Model2 - Acc:10.0 % - Loss:2.302797557353973 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=6 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 7/30] ✓  time=55.84s  cumulative=385.71s
#   [Epoch 8/30] threads started …
# Agent 7 start
# Agent 5 start
# Agent 0 start
# Agent 8 start
# Agent 6 start
# Agent 9 start
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 1 start
# Model7 - Acc:9.88 % - Loss:2.3029474382400514 %
# Model5 - Acc:10.18 % - Loss:2.3027430176734924 %
# Model0 - Acc:9.94 % - Loss:2.3027028880119325 %
# Model8 - Acc:10.04 % - Loss:2.3027359113693238 %
# Model6 - Acc:10.0 % - Loss:2.3025506381988525 %
# Model9 - Acc:9.54 % - Loss:2.3029543747901915 %
# Model3 - Acc:10.18 % - Loss:2.3027355670928955 %
# Model2 - Acc:9.46 % - Loss:2.302852837562561 %
# Model4 - Acc:10.22 % - Loss:2.302777820587158 %
# Model1 - Acc:10.36 % - Loss:2.302653974533081 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=7 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 8/30] ✓  time=55.29s  cumulative=441.00s
#   [Epoch 9/30] threads started …
# Agent 2 start
# Agent 0 start
# Agent 9 start
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 5 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Model2 - Acc:9.54 % - Loss:2.302885278224945 %
# Model0 - Acc:9.98 % - Loss:2.302724695682526 %
# Model9 - Acc:9.26 % - Loss:2.3029170117378235 %
# Model8 - Acc:10.52 % - Loss:2.3026776566505434 %
# Model1 - Acc:9.36 % - Loss:2.302683425426483 %
# Model7 - Acc:9.38 % - Loss:2.302889489650726 %
# Model5 - Acc:9.74 % - Loss:2.3026889481544495 %
# Model3 - Acc:10.22 % - Loss:2.302776756286621 %
# Model6 - Acc:10.0 % - Loss:2.3024831948280333 %
# Model4 - Acc:10.06 % - Loss:2.3028004117012024 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=8 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 9/30] ✓  time=56.02s  cumulative=497.01s
#   [Epoch 10/30] threads started …
# Agent 3 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 4 start
# Agent 5 start
# Agent 6 start
# Agent 8 start
# Agent 7 start
# Agent 0 start
# Model3 - Acc:10.02 % - Loss:2.3027156324386597 %
# Model2 - Acc:9.94 % - Loss:2.3027946944236755 %
# Model9 - Acc:9.66 % - Loss:2.30292419052124 %
# Model1 - Acc:9.56 % - Loss:2.3026498856544495 %
# Model4 - Acc:9.88 % - Loss:2.302841491222382 %
# Model5 - Acc:9.44 % - Loss:2.3026720623970034 %
# Model6 - Acc:9.76 % - Loss:2.302549189090729 %
# Model8 - Acc:9.72 % - Loss:2.3027832493782046 %
# Model7 - Acc:9.86 % - Loss:2.3028905124664307 %
# Model0 - Acc:10.02 % - Loss:2.302699224472046 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=9 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 10/30] ✓  time=57.83s  cumulative=554.85s
#   [Epoch 11/30] threads started …
# Agent 5 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Agent 0 start
# Agent 2 start
# Agent 8 start
# Agent 7 start
# Agent 9 start
# Agent 1 start
# Model5 - Acc:9.48 % - Loss:2.3026686263084413 %
# Model3 - Acc:10.08 % - Loss:2.3027184796333313 %
# Model6 - Acc:9.9 % - Loss:2.3025172257423403 %
# Model4 - Acc:9.92 % - Loss:2.302789239406586 %
# Model2 - Acc:9.64 % - Loss:2.3027856917381286 %
# Model0 - Acc:10.2 % - Loss:2.30272936296463 %
# Model8 - Acc:9.82 % - Loss:2.3027059602737427 %
# Model7 - Acc:9.9 % - Loss:2.3028794646263124 %
# Model9 - Acc:9.72 % - Loss:2.3029188394546507 %
# Model1 - Acc:9.74 % - Loss:2.3026605439186096 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=10 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 11/30] ✓  time=56.27s  cumulative=611.12s
#   [Epoch 12/30] threads started …
# Agent 5 start
# Agent 8 start
# Agent 6 start
# Agent 0 start
# Agent 7 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 4 start
# Agent 3 start
# Model5 - Acc:9.72 % - Loss:2.3027192273139954 %
# Model8 - Acc:9.88 % - Loss:2.3026957907676695 %
# Model6 - Acc:10.1 % - Loss:2.302532639980316 %
# Model0 - Acc:9.58 % - Loss:2.302756928443909 %
# Model7 - Acc:9.22 % - Loss:2.302946482658386 %
# Model2 - Acc:9.0 % - Loss:2.3028677034378053 %
# Model9 - Acc:9.58 % - Loss:2.3028985061645506 %
# Model1 - Acc:10.02 % - Loss:2.3026756262779235 %
# Model3 - Acc:9.96 % - Loss:2.302722702503204 %
# Model4 - Acc:9.86 % - Loss:2.3028038859367372 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=11 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 12/30] ✓  time=54.95s  cumulative=666.07s
#   [Epoch 13/30] threads started …
# Agent 0 start
# Agent 9 start
# Agent 7 start
# Agent 3 start
# Agent 8 start
# Agent 2 start
# Agent 1 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Model0 - Acc:9.92 % - Loss:2.3027484154701234 %
# Model9 - Acc:10.22 % - Loss:2.3028689913749694 %
# Model7 - Acc:9.38 % - Loss:2.3028758821487427 %
# Model8 - Acc:10.5 % - Loss:2.302703643798828 %
# Model2 - Acc:9.72 % - Loss:2.3027542276382444 %
# Model3 - Acc:9.94 % - Loss:2.302744342327118 %
# Model1 - Acc:10.42 % - Loss:2.302647529602051 %
# Model4 - Acc:9.62 % - Loss:2.302788674354553 %
# Model5 - Acc:10.0 % - Loss:2.3026809000968935 %
# Model6 - Acc:10.2 % - Loss:2.302518280506134 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=12 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 13/30] ✓  time=55.99s  cumulative=722.06s
#   [Epoch 14/30] threads started …
# Agent 1 start
# Agent 2 start
# Agent 3 start
# Agent 9 start
# Agent 4 start
# Agent 6 start
# Agent 7 start
# Agent 0 start
# Agent 5 start
# Agent 8 start
# Model1 - Acc:10.14 % - Loss:2.302631398200989 %
# Model2 - Acc:8.76 % - Loss:2.3028031673431397 %
# Model3 - Acc:10.12 % - Loss:2.3027403450012205 %
# Model9 - Acc:9.54 % - Loss:2.302904897689819 %
# Model4 - Acc:9.54 % - Loss:2.302794853687286 %
# Model6 - Acc:10.06 % - Loss:2.3025652627944946 %
# Model7 - Acc:9.36 % - Loss:2.3028856201171877 %
# Model5 - Acc:9.72 % - Loss:2.30268578004837 %
# Model0 - Acc:10.42 % - Loss:2.3027243452072144 %
# Model8 - Acc:10.52 % - Loss:2.302656485557556 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=13 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 14/30] ✓  time=57.30s  cumulative=779.35s
#   [Epoch 15/30] threads started …
# Agent 5 start
# Agent 4 start
# Agent 3 start
# Agent 6 start
# Agent 0 start
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 8 start
# Agent 7 start
# Model5 - Acc:9.28 % - Loss:2.3026597032546996 %
# Model4 - Acc:9.6 % - Loss:2.3028262591362 %
# Model3 - Acc:9.72 % - Loss:2.30274693107605 %
# Model6 - Acc:9.6 % - Loss:2.302507073402405 %
# Model0 - Acc:10.36 % - Loss:2.302751799106598 %
# Model1 - Acc:9.86 % - Loss:2.302617028713226 %
# Model9 - Acc:9.66 % - Loss:2.302888033390045 %
# Model2 - Acc:9.08 % - Loss:2.302771315574646 %
# Model8 - Acc:10.44 % - Loss:2.3027138843536377 %
# Model7 - Acc:9.88 % - Loss:2.302866105079651 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=14 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 15/30] ✓  time=56.42s  cumulative=835.78s
#   [Epoch 16/30] threads started …
# Agent 7 start
# Agent 5 start
# Agent 6 start
# Agent 0 start
# Agent 8 start
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Agent 1 start
# Agent 9 start
# Model7 - Acc:9.8 % - Loss:2.3028813004493713 %
# Model5 - Acc:10.14 % - Loss:2.302648228645325 %
# Model6 - Acc:9.84 % - Loss:2.3026221413612364 %
# Model0 - Acc:9.42 % - Loss:2.3026972861289976 %
# Model8 - Acc:10.0 % - Loss:2.3027194266319273 %
# Model2 - Acc:9.98 % - Loss:2.3028403329849243 %
# Model4 - Acc:10.02 % - Loss:2.3027732582092284 %
# Model1 - Acc:10.24 % - Loss:2.3026360387802125 %
# Model3 - Acc:9.6 % - Loss:2.302725089550018 %
# Model9 - Acc:10.04 % - Loss:2.302866882801056 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=15 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 16/30] ✓  time=53.79s  cumulative=889.57s
#   [Epoch 17/30] threads started …
# Agent 2 start
# Agent 1 start
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Agent 8 start
# Agent 9 start
# Agent 3 start
# Agent 4 start
# Agent 5 start
# Model2 - Acc:9.6 % - Loss:2.3027905440330505 %
# Model1 - Acc:10.06 % - Loss:2.3026086049079897 %
# Model0 - Acc:10.26 % - Loss:2.3027645077705383 %
# Model7 - Acc:9.92 % - Loss:2.3029181480407717 %
# Model8 - Acc:9.8 % - Loss:2.30269007062912 %
# Model9 - Acc:9.82 % - Loss:2.302870701789856 %
# Model6 - Acc:10.16 % - Loss:2.302528123855591 %
# Model3 - Acc:9.62 % - Loss:2.3027463850975036 %
# Model4 - Acc:9.46 % - Loss:2.3027517566680906 %
# Model5 - Acc:10.22 % - Loss:2.302667417049408 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=16 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 17/30] ✓  time=56.31s  cumulative=945.88s
#   [Epoch 18/30] threads started …
# Agent 3 start
# Agent 2 start
# Agent 8 start
# Agent 1 start
# Agent 9 start
# Agent 4 start
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 0 start
# Model3 - Acc:9.58 % - Loss:2.302718336582184 %
# Model2 - Acc:9.74 % - Loss:2.302826196193695 %
# Model1 - Acc:9.72 % - Loss:2.302607867717743 %
# Model9 - Acc:9.46 % - Loss:2.302863911628723 %
# Model4 - Acc:9.68 % - Loss:2.302775867462158 %
# Model8 - Acc:10.14 % - Loss:2.30265785074234 %
# Model7 - Acc:9.0 % - Loss:2.302885980129242 %
# Model6 - Acc:9.94 % - Loss:2.302528703212738 %
# Model5 - Acc:9.78 % - Loss:2.3026783514022826 %
# Model0 - Acc:9.7 % - Loss:2.3027629942893983 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=17 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 18/30] ✓  time=54.19s  cumulative=1000.07s
#   [Epoch 19/30] threads started …
# Agent 3 start
# Agent 5 start
# Agent 6 start
# Agent 4 start
# Agent 2 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 8 start
# Agent 7 start
# Model3 - Acc:9.78 % - Loss:2.302731715679169 %
# Model5 - Acc:9.7 % - Loss:2.3026793375015258 %
# Model6 - Acc:9.48 % - Loss:2.3024922113418578 %
# Model4 - Acc:8.94 % - Loss:2.3027721085548403 %
# Model2 - Acc:9.22 % - Loss:2.302783459663391 %
# Model0 - Acc:10.36 % - Loss:2.3027192058563233 %
# Model9 - Acc:9.18 % - Loss:2.3028617610931397 %
# Model1 - Acc:10.2 % - Loss:2.302591739177704 %
# Model8 - Acc:9.74 % - Loss:2.302683238506317 %
# Model7 - Acc:9.44 % - Loss:2.302899811267853 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=18 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 19/30] ✓  time=57.93s  cumulative=1058.00s
#   [Epoch 20/30] threads started …
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Agent 8 start
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 1 start
# Agent 9 start
# Model0 - Acc:9.8 % - Loss:2.302715874195099 %
# Model7 - Acc:9.84 % - Loss:2.3028557057380676 %
# Model6 - Acc:10.18 % - Loss:2.302472065448761 %
# Model8 - Acc:10.62 % - Loss:2.302651975154877 %
# Model5 - Acc:10.24 % - Loss:2.302692193031311 %
# Model3 - Acc:10.14 % - Loss:2.302736306667328 %
# Model4 - Acc:9.34 % - Loss:2.302820182323456 %
# Model2 - Acc:9.48 % - Loss:2.3027769174575807 %
# Model1 - Acc:10.1 % - Loss:2.302653760433197 %
# Model9 - Acc:9.76 % - Loss:2.3028759899139404 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=19 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 20/30] ✓  time=55.35s  cumulative=1113.35s
#   [Epoch 21/30] threads started …
# Agent 1 start
# Agent 3 start
# Agent 9 start
# Agent 0 start
# Agent 2 start
# Agent 7 start
# Agent 8 start
# Agent 5 start
# Agent 6 start
# Agent 4 start
# Model1 - Acc:9.98 % - Loss:2.3026755394935607 %
# Model9 - Acc:9.54 % - Loss:2.302891812801361 %
# Model0 - Acc:10.26 % - Loss:2.3026209192276 %
# Model3 - Acc:9.92 % - Loss:2.302751165866852 %
# Model2 - Acc:10.02 % - Loss:2.3028367528915403 %
# Model7 - Acc:10.16 % - Loss:2.3029030952453615 %
# Model8 - Acc:10.62 % - Loss:2.3026766037940978 %
# Model5 - Acc:9.4 % - Loss:2.30266969537735 %
# Model6 - Acc:10.04 % - Loss:2.3024887466430664 %
# Model4 - Acc:9.82 % - Loss:2.3028230152130127 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=20 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 21/30] ✓  time=55.87s  cumulative=1169.22s
#   [Epoch 22/30] threads started …
# Agent 9 start
# Agent 3 start
# Agent 4 start
# Agent 2 start
# Agent 1 start
# Agent 6 start
# Agent 7 start
# Agent 5 start
# Agent 8 start
# Agent 0 start
# Model9 - Acc:10.1 % - Loss:2.3028222193717958 %
# Model3 - Acc:9.4 % - Loss:2.3027730536460878 %
# Model4 - Acc:9.54 % - Loss:2.302800618171692 %
# Model2 - Acc:9.8 % - Loss:2.3028267970085143 %
# Model1 - Acc:9.9 % - Loss:2.302603685379028 %
# Model6 - Acc:9.52 % - Loss:2.302494936466217 %
# Model7 - Acc:9.46 % - Loss:2.302856921672821 %
# Model5 - Acc:9.68 % - Loss:2.3026773710250854 %
# Model8 - Acc:10.2 % - Loss:2.3026661396026613 %
# Model0 - Acc:9.92 % - Loss:2.3026899271011354 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=21 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 22/30] ✓  time=56.11s  cumulative=1225.34s
#   [Epoch 23/30] threads started …
# Agent 6 start
# Agent 3 start
# Agent 4 start
# Agent 5 start
# Agent 7 start
# Agent 2 start
# Agent 9 start
# Agent 8 start
# Agent 0 start
# Agent 1 start
# Model6 - Acc:10.12 % - Loss:2.3024779376983644 %
# Model3 - Acc:9.52 % - Loss:2.3027359070777895 %
# Model4 - Acc:10.1 % - Loss:2.3027064919471742 %
# Model5 - Acc:9.38 % - Loss:2.302659788608551 %
# Model7 - Acc:10.26 % - Loss:2.3029106426239014 %
# Model2 - Acc:9.08 % - Loss:2.3027975625991823 %
# Model9 - Acc:9.26 % - Loss:2.3028755106925964 %
# Model8 - Acc:9.78 % - Loss:2.302662663459778 %
# Model0 - Acc:10.02 % - Loss:2.30270703792572 %
# Model1 - Acc:10.42 % - Loss:2.3026406197547913 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=22 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 23/30] ✓  time=57.57s  cumulative=1282.91s
#   [Epoch 24/30] threads started …
# Agent 7 start
# Agent 6 start
# Agent 4 start
# Agent 5 start
# Agent 1 start
# Agent 2 start
# Agent 0 start
# Agent 9 start
# Agent 8 start
# Agent 3 start
# Model7 - Acc:9.56 % - Loss:2.302862186431885 %
# Model6 - Acc:9.38 % - Loss:2.3025111360549926 %
# Model4 - Acc:9.64 % - Loss:2.30279872751236 %
# Model5 - Acc:10.16 % - Loss:2.302652985572815 %
# Model1 - Acc:10.22 % - Loss:2.3026591739654543 %
# Model2 - Acc:9.26 % - Loss:2.302768446445465 %
# Model0 - Acc:9.62 % - Loss:2.302649017333984 %
# Model9 - Acc:9.68 % - Loss:2.3028961534500123 %
# Model8 - Acc:10.16 % - Loss:2.302671962738037 %
# Model3 - Acc:9.9 % - Loss:2.3027631640434265 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=23 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 24/30] ✓  time=55.18s  cumulative=1338.09s
#   [Epoch 25/30] threads started …
# Agent 0 start
# Agent 6 start
# Agent 7 start
# Agent 9 start
# Agent 8 start
# Agent 1 start
# Agent 4 start
# Agent 5 start
# Agent 3 start
# Agent 2 start
# Model0 - Acc:10.06 % - Loss:2.3027277789115908 %
# Model6 - Acc:9.5 % - Loss:2.30244030380249 %
# Model7 - Acc:9.94 % - Loss:2.302870108604431 %
# Model9 - Acc:9.8 % - Loss:2.302861046791077 %
# Model8 - Acc:10.32 % - Loss:2.3026936221122742 %
# Model1 - Acc:10.54 % - Loss:2.302584475040436 %
# Model4 - Acc:9.82 % - Loss:2.3028010306358335 %
# Model5 - Acc:9.16 % - Loss:2.302726435184479 %
# Model3 - Acc:9.98 % - Loss:2.3026830339431763 %
# Model2 - Acc:9.4 % - Loss:2.302753969192505 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=24 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 25/30] ✓  time=54.50s  cumulative=1392.59s
#   [Epoch 26/30] threads started …
# Agent 2 start
# Agent 9 start
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 7 start
# Agent 6 start
# Model2 - Acc:9.28 % - Loss:2.3027610630989073 %
# Model9 - Acc:9.94 % - Loss:2.302882897853851 %
# Model0 - Acc:10.14 % - Loss:2.3026588139533994 %
# Model1 - Acc:10.16 % - Loss:2.302575174331665 %
# Model8 - Acc:9.94 % - Loss:2.3026796069145203 %
# Model3 - Acc:10.06 % - Loss:2.3027477989196776 %
# Model5 - Acc:9.56 % - Loss:2.3026730904579162 %
# Model4 - Acc:10.14 % - Loss:2.3027594628334045 %
# Model7 - Acc:9.52 % - Loss:2.302892737388611 %
# Model6 - Acc:9.86 % - Loss:2.302440483570099 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=25 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 26/30] ✓  time=57.37s  cumulative=1449.96s
#   [Epoch 27/30] threads started …
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 5 start
# Agent 7 start
# Agent 9 start
# Agent 0 start
# Agent 8 start
# Agent 1 start
# Agent 6 start
# Model3 - Acc:9.94 % - Loss:2.3026866235733032 %
# Model2 - Acc:10.04 % - Loss:2.3027266926765444 %
# Model4 - Acc:9.96 % - Loss:2.30275878572464 %
# Model5 - Acc:10.2 % - Loss:2.3026742305755614 %
# Model7 - Acc:9.62 % - Loss:2.3028790736198426 %
# Model9 - Acc:9.62 % - Loss:2.302842391014099 %
# Model0 - Acc:10.0 % - Loss:2.302701596260071 %
# Model8 - Acc:10.66 % - Loss:2.302589964389801 %
# Model1 - Acc:10.34 % - Loss:2.302568994522095 %
# Model6 - Acc:9.86 % - Loss:2.3023759822845458 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=26 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 27/30] ✓  time=58.33s  cumulative=1508.29s
#   [Epoch 28/30] threads started …
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Agent 5 start
# Agent 3 start
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 8 start
# Agent 0 start
# Model6 - Acc:10.22 % - Loss:2.3023713479042054 %
# Model4 - Acc:10.06 % - Loss:2.3027343225479124 %
# Model7 - Acc:9.86 % - Loss:2.302790138244629 %
# Model5 - Acc:9.88 % - Loss:2.302671886920929 %
# Model3 - Acc:9.96 % - Loss:2.302660029888153 %
# Model1 - Acc:9.94 % - Loss:2.3026062870025634 %
# Model9 - Acc:9.36 % - Loss:2.3028778247833253 %
# Model2 - Acc:10.06 % - Loss:2.3027553176879882 %
# Model8 - Acc:9.86 % - Loss:2.3026948189735412 %
# Model0 - Acc:10.12 % - Loss:2.3026723556518554 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=27 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 28/30] ✓  time=53.88s  cumulative=1562.17s
#   [Epoch 29/30] threads started …
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 0 start
# Agent 9 start
# Agent 6 start
# Agent 2 start
# Agent 3 start
# Agent 4 start
# Agent 5 start
# Model8 - Acc:10.48 % - Loss:2.3026388659477233 %
# Model1 - Acc:10.36 % - Loss:2.3025266523361205 %
# Model7 - Acc:9.84 % - Loss:2.302772539615631 %
# Model0 - Acc:10.18 % - Loss:2.3026694126129152 %
# Model9 - Acc:9.94 % - Loss:2.3028110513687134 %
# Model6 - Acc:10.0 % - Loss:2.3023998527526857 %
# Model2 - Acc:10.1 % - Loss:2.302699899673462 %
# Model3 - Acc:10.24 % - Loss:2.302658302783966 %
# Model4 - Acc:9.92 % - Loss:2.3026780672073364 %
# Model5 - Acc:10.16 % - Loss:2.302591540813446 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=28 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 29/30] ✓  time=55.78s  cumulative=1617.95s
#   [Epoch 30/30] threads started …
# Agent 8 start
# Agent 1 start
# Agent 2 start
# Agent 9 start
# Agent 3 start
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Model8 - Acc:10.18 % - Loss:2.302578107357025 %
# Model1 - Acc:9.48 % - Loss:2.3025306606292726 %
# Model2 - Acc:9.72 % - Loss:2.3027441573143004 %
# Model9 - Acc:9.4 % - Loss:2.3028282222747802 %
# Model3 - Acc:10.08 % - Loss:2.302654279232025 %
# Model0 - Acc:10.14 % - Loss:2.302655364990234 %
# Model7 - Acc:9.7 % - Loss:2.302757227420807 %
# Model6 - Acc:9.68 % - Loss:2.3024740753173827 %
# Model5 - Acc:9.56 % - Loss:2.3026385726928713 %
# Model4 - Acc:9.92 % - Loss:2.302734551906586 %
# [DEBUG] set_epoch_messages called → 450 messages
#     → avrg distance after iteration 1: 0.000000
#     → avrg distance after iteration 2: 0.000000
#     → avrg distance after iteration 3: 0.000000
#     → avrg distance after iteration 4: 0.000000
#     → avrg distance after iteration 5: 0.000000
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
# [DEBUG] _record epoch=29 → n_messages=450
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 450
#   [Epoch 30/30] ✓  time=55.93s  cumulative=1673.87s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=30 | total=1673.87s | mean=55.80s/ep | fastest=ep4(46.72s) | slowest=ep6(62.78s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : AC_fully_connected_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 11.12%
#   Val Loss  finale : 2.3025
#   Temps total      : 1673.87s
#   Temps moyen/ép.  : 55.80s
#   Époque la + rapide : ép.4 (46.72s)
#   Époque la + lente  : ép.6 (62.78s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_fully_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 3193.211 MB
#     Total messages    : 13,500
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 669.78 ms
#     Synchro totale    : 20093.3 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_fully_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 3193.211 MB
#     Total messages    : 13,500
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 669.78 ms
#     Synchro totale    : 20093.3 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ============================================================
#   RUN — méthode : AC_cycle_graph
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/30] threads started …
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 5 start
# Agent 1 start
# Agent 8 start
# Agent 0 start
# Agent 9 start
# Agent 6 start
# Agent 7 start
# Model4 - Acc:10.36 % - Loss:2.3042401552200316 %
# Model2 - Acc:10.26 % - Loss:2.3022162890434266 %
# Model3 - Acc:11.26 % - Loss:2.30053729057312 %
# Model5 - Acc:11.1 % - Loss:2.2991253933906557 %
# Model1 - Acc:11.3 % - Loss:2.3035854172706602 %
# Model8 - Acc:10.58 % - Loss:2.302242123126984 %
# Model0 - Acc:14.24 % - Loss:2.2976590123176575 %
# Model9 - Acc:11.12 % - Loss:2.297829351425171 %
# Model6 - Acc:9.92 % - Loss:2.30356235742569 %
# Model7 - Acc:10.88 % - Loss:2.2987360877990723 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 4.292333
#     → avrg distance after iteration 2: 3.256567
#     → avrg distance after iteration 3: 2.711909
#     → avrg distance after iteration 4: 2.325534
#     → avrg distance after iteration 5: 2.015946
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=0 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 1/30] ✓  time=55.82s  cumulative=55.82s
#   [Epoch 2/30] threads started …
# Agent 4 start
# Agent 5 start
# Agent 6 start
# Agent 7 start
# Agent 8 start
# Agent 2 start
# Agent 0 start
# Agent 3 start
# Agent 1 start
# Agent 9 start
# Model4 - Acc:10.34 % - Loss:2.302838597774506 %
# Model5 - Acc:10.8 % - Loss:2.3023844714164734 %
# Model6 - Acc:10.42 % - Loss:2.302041532039642 %
# Model7 - Acc:10.24 % - Loss:2.3027785120010376 %
# Model8 - Acc:9.76 % - Loss:2.3029190092086793 %
# Model2 - Acc:10.4 % - Loss:2.3026480741500857 %
# Model0 - Acc:10.18 % - Loss:2.302434572696686 %
# Model3 - Acc:10.12 % - Loss:2.302327670097351 %
# Model1 - Acc:10.2 % - Loss:2.3028397483825684 %
# Model9 - Acc:9.98 % - Loss:2.302886137962341 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 1.755206
#     → avrg distance after iteration 2: 1.530194
#     → avrg distance after iteration 3: 1.334860
#     → avrg distance after iteration 4: 1.164735
#     → avrg distance after iteration 5: 1.016382
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=1 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 2/30] ✓  time=53.57s  cumulative=109.39s
#   [Epoch 3/30] threads started …
# Agent 1 start
# Agent 6 start
# Agent 9 start
# Agent 7 start
# Agent 8 start
# Agent 0 start
# Agent 5 start
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Model1 - Acc:9.7 % - Loss:2.3027806663513184 %
# Model6 - Acc:10.6 % - Loss:2.302108160018921 %
# Model9 - Acc:10.1 % - Loss:2.302781596660614 %
# Model7 - Acc:9.98 % - Loss:2.302623411655426 %
# Model8 - Acc:9.26 % - Loss:2.3029259490966796 %
# Model0 - Acc:10.7 % - Loss:2.302432026863098 %
# Model3 - Acc:10.6 % - Loss:2.302309467792511 %
# Model5 - Acc:10.74 % - Loss:2.302279892921448 %
# Model2 - Acc:10.5 % - Loss:2.3024763579368592 %
# Model4 - Acc:9.18 % - Loss:2.302754357337952 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.887672
#     → avrg distance after iteration 2: 0.774565
#     → avrg distance after iteration 3: 0.675926
#     → avrg distance after iteration 4: 0.589860
#     → avrg distance after iteration 5: 0.514756
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=2 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 3/30] ✓  time=52.73s  cumulative=162.12s
#   [Epoch 4/30] threads started …
# Agent 2 start
# Agent 1 start
# Agent 8 start
# Agent 9 start
# Agent 0 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Agent 5 start
# Model2 - Acc:10.46 % - Loss:2.302469400405884 %
# Model1 - Acc:9.58 % - Loss:2.3027658438682557 %
# Model8 - Acc:10.02 % - Loss:2.3028658418655397 %
# Model9 - Acc:10.08 % - Loss:2.302770577430725 %
# Model0 - Acc:10.36 % - Loss:2.3024217052459717 %
# Model3 - Acc:11.04 % - Loss:2.302305850982666 %
# Model6 - Acc:10.88 % - Loss:2.302158450603485 %
# Model4 - Acc:9.62 % - Loss:2.3026650881767274 %
# Model7 - Acc:10.44 % - Loss:2.3025998911857606 %
# Model5 - Acc:10.76 % - Loss:2.3022483620643617 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.450567
#     → avrg distance after iteration 2: 0.393045
#     → avrg distance after iteration 3: 0.342971
#     → avrg distance after iteration 4: 0.299294
#     → avrg distance after iteration 5: 0.261184
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=3 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 4/30] ✓  time=57.71s  cumulative=219.84s
#   [Epoch 5/30] threads started …
# Agent 3 start
# Agent 5 start
# Agent 2 start
# Agent 4 start
# Agent 7 start
# Agent 8 start
# Agent 9 start
# Agent 1 start
# Agent 6 start
# Agent 0 start
# Model3 - Acc:10.56 % - Loss:2.3023391809463503 %
# Model5 - Acc:10.58 % - Loss:2.302247049808502 %
# Model2 - Acc:10.56 % - Loss:2.302399881362915 %
# Model4 - Acc:9.92 % - Loss:2.302679561138153 %
# Model7 - Acc:10.3 % - Loss:2.30261922454834 %
# Model9 - Acc:9.96 % - Loss:2.3027365403175355 %
# Model8 - Acc:9.44 % - Loss:2.3029283442497253 %
# Model1 - Acc:10.32 % - Loss:2.3027429194450377 %
# Model6 - Acc:10.76 % - Loss:2.30209752702713 %
# Model0 - Acc:10.7 % - Loss:2.3025317687988283 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.230814
#     → avrg distance after iteration 2: 0.201092
#     → avrg distance after iteration 3: 0.175416
#     → avrg distance after iteration 4: 0.153060
#     → avrg distance after iteration 5: 0.133565
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=4 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 5/30] ✓  time=57.83s  cumulative=277.67s
#   [Epoch 6/30] threads started …
# Agent 5 start
# Agent 4 start
# Agent 6 start
# Agent 7 start
# Agent 1 start
# Agent 0 start
# Agent 3 start
# Agent 9 start
# Agent 8 start
# Agent 2 start
# Model5 - Acc:10.74 % - Loss:2.302264527797699 %
# Model4 - Acc:9.82 % - Loss:2.302607264995575 %
# Model6 - Acc:11.0 % - Loss:2.302099036216736 %
# Model7 - Acc:10.24 % - Loss:2.3025715589523315 %
# Model1 - Acc:10.42 % - Loss:2.3027222738265993 %
# Model3 - Acc:11.04 % - Loss:2.3023255305290222 %
# Model0 - Acc:10.38 % - Loss:2.30255889749527 %
# Model9 - Acc:10.34 % - Loss:2.3027701907157896 %
# Model8 - Acc:9.32 % - Loss:2.3028563928604124 %
# Model2 - Acc:10.28 % - Loss:2.3023649706840517 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.121534
#     → avrg distance after iteration 2: 0.105459
#     → avrg distance after iteration 3: 0.091907
#     → avrg distance after iteration 4: 0.080168
#     → avrg distance after iteration 5: 0.069949
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=5 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 6/30] ✓  time=53.48s  cumulative=331.14s
#   [Epoch 7/30] threads started …
# Agent 9 start
# Agent 1 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Agent 6 start
# Agent 4 start
# Agent 3 start
# Agent 2 start
# Agent 5 start
# Model9 - Acc:9.84 % - Loss:2.3027943120002745 %
# Model1 - Acc:10.2 % - Loss:2.30276580619812 %
# Model0 - Acc:10.14 % - Loss:2.3025527873039247 %
# Model8 - Acc:8.62 % - Loss:2.3027941727638246 %
# Model7 - Acc:10.12 % - Loss:2.3025589623451235 %
# Model6 - Acc:11.04 % - Loss:2.302142900466919 %
# Model4 - Acc:10.22 % - Loss:2.302656967163086 %
# Model3 - Acc:10.96 % - Loss:2.302307842254639 %
# Model2 - Acc:10.3 % - Loss:2.3024001417160034 %
# Model5 - Acc:10.98 % - Loss:2.302267652511597 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.069921
#     → avrg distance after iteration 2: 0.060077
#     → avrg distance after iteration 3: 0.052244
#     → avrg distance after iteration 4: 0.045536
#     → avrg distance after iteration 5: 0.039720
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=6 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 7/30] ✓  time=56.54s  cumulative=387.68s
#   [Epoch 8/30] threads started …
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 0 start
# Agent 8 start
# Agent 4 start
# Agent 3 start
# Agent 5 start
# Agent 6 start
# Agent 7 start
# Model1 - Acc:9.8 % - Loss:2.3027234964370726 %
# Model9 - Acc:10.02 % - Loss:2.302690097332001 %
# Model2 - Acc:10.62 % - Loss:2.3023189148902894 %
# Model0 - Acc:10.6 % - Loss:2.3025444474220276 %
# Model8 - Acc:8.7 % - Loss:2.302910138130188 %
# Model3 - Acc:11.04 % - Loss:2.3022737684249877 %
# Model4 - Acc:9.66 % - Loss:2.3026340041160585 %
# Model5 - Acc:10.34 % - Loss:2.302225877761841 %
# Model6 - Acc:10.96 % - Loss:2.302040012359619 %
# Model7 - Acc:10.32 % - Loss:2.3025497336387635 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.049321
#     → avrg distance after iteration 2: 0.041644
#     → avrg distance after iteration 3: 0.036064
#     → avrg distance after iteration 4: 0.031387
#     → avrg distance after iteration 5: 0.027364
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=7 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 8/30] ✓  time=62.50s  cumulative=450.18s
#   [Epoch 9/30] threads started …
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 8 start
# Agent 0 start
# Agent 9 start
# Agent 7 start
# Agent 6 start
# Agent 1 start
# Model5 - Acc:10.98 % - Loss:2.3021825675964354 %
# Model4 - Acc:9.72 % - Loss:2.3026324305534365 %
# Model2 - Acc:10.62 % - Loss:2.3023435707092283 %
# Model3 - Acc:10.68 % - Loss:2.302372262954712 %
# Model8 - Acc:9.56 % - Loss:2.3029169101715086 %
# Model0 - Acc:10.48 % - Loss:2.302544270992279 %
# Model9 - Acc:9.78 % - Loss:2.3027142419815063 %
# Model7 - Acc:10.16 % - Loss:2.3025519132614134 %
# Model6 - Acc:11.0 % - Loss:2.3020034217834473 %
# Model1 - Acc:9.98 % - Loss:2.302770308971405 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.042546
#     → avrg distance after iteration 2: 0.035377
#     → avrg distance after iteration 3: 0.030532
#     → avrg distance after iteration 4: 0.026532
#     → avrg distance after iteration 5: 0.023121
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=8 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 9/30] ✓  time=62.77s  cumulative=512.95s
#   [Epoch 10/30] threads started …
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Agent 4 start
# Agent 0 start
# Agent 8 start
# Agent 3 start
# Agent 1 start
# Agent 2 start
# Agent 9 start
# Model7 - Acc:10.06 % - Loss:2.302606686592102 %
# Model6 - Acc:10.4 % - Loss:2.3019781494140625 %
# Model5 - Acc:10.22 % - Loss:2.302225887775421 %
# Model4 - Acc:9.74 % - Loss:2.302607364177704 %
# Model0 - Acc:10.38 % - Loss:2.302532308101654 %
# Model8 - Acc:9.66 % - Loss:2.302878557682037 %
# Model1 - Acc:10.22 % - Loss:2.3028136496543885 %
# Model3 - Acc:11.04 % - Loss:2.302329216957092 %
# Model2 - Acc:10.36 % - Loss:2.302331765174866 %
# Model9 - Acc:9.68 % - Loss:2.302751461029053 %
# [DEBUG] set_epoch_messages called → 100 messages
# ...
#     → avrg distance after iteration 4: 0.010851
#     → avrg distance after iteration 5: 0.008912
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 130
# [DEBUG] _record epoch=23 → n_messages=130
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 130
#   [Epoch 24/30] ✓  time=32.72s  cumulative=872.87s
#   [Epoch 25/30] threads started …
# Agent 3 start
# Agent 4 start
# Agent 5 start
# Agent 6 start
# Agent 1 start
# Agent 8 start
# Agent 2 start
# Agent 0 start
# Agent 9 start
# Agent 7 start
# Model4 - Acc:10.16 % - Loss:2.3027463574409484 %
# Model3 - Acc:9.84 % - Loss:2.302797618865967 %
# Model5 - Acc:10.58 % - Loss:2.302778162956238 %
# Model6 - Acc:10.22 % - Loss:2.3026215581893923 %
# Model1 - Acc:10.3 % - Loss:2.3026199688911437 %
# Model8 - Acc:10.52 % - Loss:2.3026228761672973 %
# Model2 - Acc:9.44 % - Loss:2.3027050008773804 %
# Model0 - Acc:10.4 % - Loss:2.30254608297348 %
# Model9 - Acc:9.54 % - Loss:2.3028309359550474 %
# Model7 - Acc:9.74 % - Loss:2.3027498569488527 %
# [DEBUG] set_epoch_messages called → 150 messages
#     → avrg distance after iteration 1: 0.021183
#     → avrg distance after iteration 2: 0.013565
#     → avrg distance after iteration 3: 0.009515
#     → avrg distance after iteration 4: 0.006938
#     → avrg distance after iteration 5: 0.005098
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 150
# [DEBUG] _record epoch=24 → n_messages=150
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 150
#   [Epoch 25/30] ✓  time=32.36s  cumulative=905.23s
#   [Epoch 26/30] threads started …
# Agent 8 start
# Agent 6 start
# Agent 7 start
# Agent 0 start
# Agent 1 start
# Agent 5 start
# Agent 3 start
# Agent 9 start
# Agent 2 start
# Agent 4 start
# Model8 - Acc:10.02 % - Loss:2.3025851616859434 %
# Model6 - Acc:10.46 % - Loss:2.3026322150230407 %
# Model7 - Acc:10.24 % - Loss:2.3027401041984557 %
# Model0 - Acc:10.72 % - Loss:2.3024972491264344 %
# Model1 - Acc:10.22 % - Loss:2.3026702327728272 %
# Model9 - Acc:9.74 % - Loss:2.3028370456695555 %
# Model3 - Acc:9.94 % - Loss:2.30273184299469 %
# Model2 - Acc:9.28 % - Loss:2.3027662415504455 %
# Model4 - Acc:9.78 % - Loss:2.3027488718032836 %
# Model5 - Acc:9.54 % - Loss:2.3028576674461365 %
# [DEBUG] set_epoch_messages called → 100 messages
#     → avrg distance after iteration 1: 0.028729
#     → avrg distance after iteration 2: 0.021316
#     → avrg distance after iteration 3: 0.017908
#     → avrg distance after iteration 4: 0.015763
#     → avrg distance after iteration 5: 0.014386
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
# [DEBUG] _record epoch=25 → n_messages=100
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 100
#   [Epoch 26/30] ✓  time=32.88s  cumulative=938.11s
#   [Epoch 27/30] threads started …
# Agent 1 start
# Agent 9 start
# Agent 0 start
# Agent 5 start
# Agent 3 start
# Agent 8 start
# Agent 2 start
# Agent 7 start
# Agent 6 start
# Agent 4 start
# Model1 - Acc:10.14 % - Loss:2.3023940424919127 %
# Model9 - Acc:9.96 % - Loss:2.3028095889091493 %
# Model0 - Acc:10.48 % - Loss:2.3024719314575197 %
# Model5 - Acc:10.28 % - Loss:2.3027868213653564 %
# Model3 - Acc:10.16 % - Loss:2.302673327922821 %
# Model8 - Acc:10.18 % - Loss:2.3025994200706483 %
# Model2 - Acc:9.76 % - Loss:2.30265145778656 %
# Model6 - Acc:10.34 % - Loss:2.3026514019966124 %
# Model4 - Acc:9.96 % - Loss:2.3027161865234373 %
# Model7 - Acc:10.12 % - Loss:2.302710584640503 %
# [DEBUG] set_epoch_messages called → 150 messages
#     → avrg distance after iteration 1: 0.021177
#     → avrg distance after iteration 2: 0.012342
#     → avrg distance after iteration 3: 0.008005
#     → avrg distance after iteration 4: 0.005386
#     → avrg distance after iteration 5: 0.003735
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 150
# [DEBUG] _record epoch=26 → n_messages=150
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 150
#   [Epoch 27/30] ✓  time=32.72s  cumulative=970.83s
#   [Epoch 28/30] threads started …
# Agent 1 start
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 0 start
# Agent 9 start
# Agent 6 start
# Agent 8 start
# Agent 7 start
# Agent 5 start
# Model3 - Acc:10.1 % - Loss:2.3027071256637575 %
# Model1 - Acc:9.58 % - Loss:2.3026734371185302 %
# Model2 - Acc:9.78 % - Loss:2.3027291297912598 %
# Model4 - Acc:9.7 % - Loss:2.3027820205688476 %
# Model0 - Acc:10.54 % - Loss:2.3025136003494264 %
# Model6 - Acc:9.8 % - Loss:2.3027232604026793 %
# Model7 - Acc:9.66 % - Loss:2.30276615524292 %
# Model9 - Acc:9.18 % - Loss:2.3028479137420654 %
# Model8 - Acc:10.28 % - Loss:2.3025922718048095 %
# Model5 - Acc:9.66 % - Loss:2.3027815227508546 %
# [DEBUG] set_epoch_messages called → 160 messages
#     → avrg distance after iteration 1: 0.019502
#     → avrg distance after iteration 2: 0.010942
#     → avrg distance after iteration 3: 0.006653
#     → avrg distance after iteration 4: 0.004285
#     → avrg distance after iteration 5: 0.002762
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 160
# [DEBUG] _record epoch=27 → n_messages=160
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 160
#   [Epoch 28/30] ✓  time=32.96s  cumulative=1003.79s
#   [Epoch 29/30] threads started …
# Agent 5 start
# Agent 6 start
# Agent 4 start
# Agent 3 start
# Agent 0 start
# Agent 2 start
# Agent 8 start
# Agent 9 start
# Agent 1 start
# Agent 7 start
# Model5 - Acc:10.24 % - Loss:2.3027953796386718 %
# Model6 - Acc:9.86 % - Loss:2.302769733905792 %
# Model4 - Acc:9.62 % - Loss:2.3027120804786683 %
# Model0 - Acc:10.34 % - Loss:2.302484715461731 %
# Model3 - Acc:10.04 % - Loss:2.302719244003296 %
# Model2 - Acc:9.46 % - Loss:2.3027065377235414 %
# Model8 - Acc:10.4 % - Loss:2.3026266527175903 %
# Model1 - Acc:9.74 % - Loss:2.3027047328948975 %
# Model7 - Acc:9.58 % - Loss:2.302732573032379 %
# Model9 - Acc:9.22 % - Loss:2.302813678264618 %
# [DEBUG] set_epoch_messages called → 80 messages
#     → avrg distance after iteration 1: 0.030348
#     → avrg distance after iteration 2: 0.024067
#     → avrg distance after iteration 3: 0.021048
#     → avrg distance after iteration 4: 0.019048
#     → avrg distance after iteration 5: 0.017738
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 80
# [DEBUG] _record epoch=28 → n_messages=80
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 80
#   [Epoch 29/30] ✓  time=32.20s  cumulative=1035.99s
#   [Epoch 30/30] threads started …
# Agent 5 start
# Agent 0 start
# Agent 7 start
# Agent 8 start
# Agent 6 start
# Agent 4 start
# Agent 2 start
# Agent 9 start
# Agent 1 start
# Agent 3 start
# Model0 - Acc:10.88 % - Loss:2.302053232192993 %
# Model5 - Acc:10.08 % - Loss:2.3028769631385804 %
# Model7 - Acc:10.3 % - Loss:2.3027166476249694 %
# Model8 - Acc:10.54 % - Loss:2.302509828567505 %
# Model6 - Acc:9.9 % - Loss:2.3025995221138 %
# Model4 - Acc:9.14 % - Loss:2.302783119678497 %
# Model2 - Acc:9.82 % - Loss:2.302643849372864 %
# Model9 - Acc:9.58 % - Loss:2.302771902561188 %
# Model1 - Acc:9.08 % - Loss:2.3025821814537046 %
# Model3 - Acc:9.44 % - Loss:2.3027522621154786 %
# [DEBUG] set_epoch_messages called → 160 messages
#     → avrg distance after iteration 1: 0.019878
#     → avrg distance after iteration 2: 0.011571
#     → avrg distance after iteration 3: 0.008070
#     → avrg distance after iteration 4: 0.006011
#     → avrg distance after iteration 5: 0.004561
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 160
# [DEBUG] _record epoch=29 → n_messages=160
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 160
#   [Epoch 30/30] ✓  time=32.33s  cumulative=1068.33s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=30 | total=1068.33s | mean=35.61s/ep | fastest=ep21(31.95s) | slowest=ep3(54.13s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : AC_random_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 10.00%
#   Val Loss  finale : 2.3028
#   Temps total      : 1068.33s
#   Temps moyen/ép.  : 35.61s
#   Époque la + rapide : ép.21 (31.95s)
#   Époque la + lente  : ép.3 (54.13s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 991.078 MB
#     Total messages    : 4,190
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 203.23 ms
#     Synchro totale    : 6096.8 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 991.078 MB
#     Total messages    : 4,190
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 203.23 ms
#     Synchro totale    : 6096.8 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════
#   CLASSEMENT FINAL — comparator.rank()
# ════════════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════════════════
#   CLASSEMENT DES MÉTHODES PAR EFFICACITÉ (accuracy / MB)
# ──────────────────────────────────────────────────────────────────────
#   Rang  Méthode                   Total MB     Synchro moy    Efficacité
# ──────────────────────────────────────────────────────────────────────
#   1     AC_fully_connected_graph  3193.211     669.78         N/A
#   2     AC_cycle_graph            709.602      479.86         N/A
#   3     AC_star_graph             638.642      581.83         N/A
#   4     AC_random_graph           991.078      203.23         N/A
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Méthode                          Val Loss    Val Acc  Train Acc
# ======================================================================
# AC_fully_connected_graph           2.3025     11.12%     10.14%
# AC_cycle_graph                     2.3025     10.00%     10.58%
# AC_star_graph                      1.6386     39.02%     38.40%
# AC_random_graph                    2.3028     10.00%     10.88%
# ======================================================================
#
# ══════════════════════════════════════════════════════════════════════
#   CLASSEMENT DES MÉTHODES PAR EFFICACITÉ (accuracy / MB)
# ──────────────────────────────────────────────────────────────────────
#   Rang  Méthode                   Total MB     Synchro moy    Efficacité
# ──────────────────────────────────────────────────────────────────────
#   1     AC_fully_connected_graph  3193.211     669.78         N/A
#   2     AC_cycle_graph            709.602      479.86         N/A
#   3     AC_star_graph             638.642      581.83         N/A
#   4     AC_random_graph           991.078      203.23         N/A
# ══════════════════════════════════════════════════════════════════════
# ═══════════════════════════════════════════════════════
#   RunResult : AC_fully_connected_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 11.12%
#   Val Loss  finale : 2.3025
#   Temps total      : 1673.87s
#   Temps moyen/ép.  : 55.80s
#   Époque la + rapide : ép.4 (46.72s)
#   Époque la + lente  : ép.6 (62.78s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_fully_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 3193.211 MB
#     Total messages    : 13,500
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 669.78 ms
#     Synchro totale    : 20093.3 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : AC_cycle_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 10.00%
#   Val Loss  finale : 2.3025
#   Temps total      : 1623.56s
#   Temps moyen/ép.  : 54.12s
#   Époque la + rapide : ép.29 (49.87s)
#   Époque la + lente  : ép.9 (62.77s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_cycle_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 709.602 MB
#     Total messages    : 3,000
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 479.86 ms
#     Synchro totale    : 14395.8 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : AC_star_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 39.02%
#   Val Loss  finale : 1.6386
#   Temps total      : 1582.01s
#   Temps moyen/ép.  : 52.73s
#   Époque la + rapide : ép.2 (50.03s)
#   Époque la + lente  : ép.20 (55.55s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_star_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 638.642 MB
#     Total messages    : 2,700
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 581.83 ms
#     Synchro totale    : 17454.9 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : AC_random_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 10.00%
#   Val Loss  finale : 2.3028
#   Temps total      : 1068.33s
#   Temps moyen/ép.  : 35.61s
#   Époque la + rapide : ép.21 (31.95s)
#   Époque la + lente  : ép.3 (54.13s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — AC_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 30
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 991.078 MB
#     Total messages    : 4,190
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 203.23 ms
#     Synchro totale    : 6096.8 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════

# %%
comparator.rank()

# %%
plot_cumulative_times(results)
plot_epoch_times(results)

# %%
comparator.plot_comparison()

# %%
print_benchmark_summary(results)

# %%
plot_all_benchmark_metrics(results)

# %%
plot_average_distance(results)

# %%
for result in results:
    print(f"\n── {result.method_name} ──")
    print(result)
    result.comm_cost.summary()

    plot_cosine_similarity(result)
    plot_distance_heatmap(result.agent_list, result.method_name)
    plot_all_agent_node_weight_metric(result.agent_list)

    result.metrics.plot_history()

# %%
def Sequential_AC_fully_connected_graph(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.fully_connected_graph(len(agent_list))

    Sequential_AC(
        agent_list,
        graph,
        comm_cost=comm_cost
    )


def Sequential_AC_cycle_graph(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.cycle_graph(len(agent_list))

    Sequential_AC(
        agent_list,
        graph,
        comm_cost=comm_cost
    )


def Sequential_AC_star_graph(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.star_graph(len(agent_list))

    Sequential_AC(
        agent_list,
        graph,
        comm_cost=comm_cost
    )


def Sequential_AC_random_graph(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.random_graph(len(agent_list))

    Sequential_AC(
        agent_list,
        graph,
        comm_cost=comm_cost
    )


# ──────────────────────────────────────────────────────────────
# Dictionnaire des méthodes à comparer
# ──────────────────────────────────────────────────────────────

COMMUNICATION_METHODS = {

    "Sequential_AC_connected_graph":
        Sequential_AC_fully_connected_graph,

    "Sequential_AC_cycle_graph":
        Sequential_AC_cycle_graph,

    "Sequential_AC_star_graph":
        Sequential_AC_star_graph,

    "Sequential_AC_random_graph":
        Sequential_AC_random_graph,
}

# --- hyperparamètres ---

RANDOM_SEED = 123
BATCH_SIZE = 10
NUM_EPOCHES = 20

MOMENTUM = 0.9
LEARING_RATE = 0.001
SCALE = 0.1
IMG_SIZE = (128, 128)
LATENT_DIM = 10
N_AGENT = 10
k = 5
# Device configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_list = generate_agent(BATCH_SIZE, N_AGENT, DEVICE)

results, comparator = benchmark_sequential(
    communication_methods=COMMUNICATION_METHODS,
    num_epochs=NUM_EPOCHES,
    graph=none,
    k=k,
    BATCH_SIZE=BATCH_SIZE,
    N_AGENT=N_AGENT,
    DEVICE=DEVICE,
)

print_benchmark_summary(results)
comparator.rank()
plot_all_benchmark_metrics(results)
plot_average_distance(results)
plot_cumulative_times(results)
plot_epoch_times(results)

for result in results:
    print(result)
    plot_cosine_similarity(result)
    plot_distance_heatmap(result.agent_list, result.method_name)
    plot_all_agent_node_weight_metric(result.agent_list)

    result.metrics.plot_history()
    result.comm_cost.summary()
# Out:
# C:\Users\flofl\PycharmProjects\IA_A_à_Z\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#
# ============================================================
#   RUN — méthode : Sequential_AC_connected_graph
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/20] threads started …
# Agent 2 start
# Agent 4 start
# Agent 5 start
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Agent 3 start
# Model2 - Acc:10.94 % - Loss:2.3010490193367006 %
# Model4 - Acc:10.08 % - Loss:2.300784317970276 %
# Agent 7 start
# Agent 6 start
# Model5 - Acc:10.4 % - Loss:2.300230820655823 %
# Agent 9 start
# Model3 - Acc:11.94 % - Loss:2.2987929925918578 %
# Model0 - Acc:10.0 % - Loss:2.3038407669067382 %
# Model1 - Acc:10.68 % - Loss:2.303235528945923 %
# Model8 - Acc:10.54 % - Loss:2.2971434993743896 %
# Model7 - Acc:12.54 % - Loss:2.2991429181098937 %
# Model6 - Acc:12.36 % - Loss:2.3011717953681945 %
# Model9 - Acc:9.06 % - Loss:2.3029245533943175 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=0 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 1/20] ✓  time=76.74s  cumulative=76.74s
#   [Epoch 2/20] threads started …
# Agent 4 start
# Agent 0 start
# Agent 5 start
# Agent 8 start
# Agent 7 start
# Agent 1 start
# Agent 3 start
# Agent 6 start
# Agent 9 start
# Agent 2 start
# Model4 - Acc:9.92 % - Loss:2.3025223269462587 %
# Model5 - Acc:9.82 % - Loss:2.3026443538665773 %
# Model7 - Acc:10.04 % - Loss:2.3021914501190186 %
# Model0 - Acc:9.74 % - Loss:2.3027160744667055 %
# Model6 - Acc:11.04 % - Loss:2.3021862773895263 %
# Model8 - Acc:10.74 % - Loss:2.2991664056777954 %
# Model1 - Acc:9.68 % - Loss:2.302873375892639 %
# Model3 - Acc:10.1 % - Loss:2.302403461456299 %
# Model9 - Acc:9.94 % - Loss:2.30111799621582 %
# Model2 - Acc:10.34 % - Loss:2.3026845598220826 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=1 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 2/20] ✓  time=73.72s  cumulative=150.47s
#   [Epoch 3/20] threads started …
# Agent 8 start
# Agent 6 start
# Agent 0 start
# Agent 9 start
# Agent 1 start
# Agent 7 start
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Agent 5 start
# Model8 - Acc:10.76 % - Loss:2.295410921573639 %
# Model6 - Acc:12.44 % - Loss:2.294367958545685 %
# Model0 - Acc:11.28 % - Loss:2.295422486305237 %
# Model9 - Acc:10.24 % - Loss:2.2944013838768007 %
# Model1 - Acc:12.7 % - Loss:2.2957630019187927 %
# Model7 - Acc:12.3 % - Loss:2.292025424003601 %
# Model2 - Acc:13.66 % - Loss:2.29533659696579 %
# Model4 - Acc:11.2 % - Loss:2.2957480392456056 %
# Model3 - Acc:12.22 % - Loss:2.295220854282379 %
# Model5 - Acc:11.9 % - Loss:2.2945758624076844 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=2 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 3/20] ✓  time=72.13s  cumulative=222.60s
#   [Epoch 4/20] threads started …
# Agent 0 start
# Agent 9 start
# Agent 2 start
# Agent 1 start
# Agent 8 start
# Agent 3 start
# Agent 7 start
# Agent 5 start
# Agent 4 start
# Agent 6 start
# Model0 - Acc:16.86 % - Loss:2.236504105091095 %
# Model9 - Acc:17.58 % - Loss:2.2413567719459535 %
# Model2 - Acc:17.28 % - Loss:2.2358820884227755 %
# Model1 - Acc:17.3 % - Loss:2.2402951905727386 %
# Model8 - Acc:17.22 % - Loss:2.245746521949768 %
# Model3 - Acc:18.08 % - Loss:2.241055202007294 %
# Model7 - Acc:16.74 % - Loss:2.2415708088874817 %
# Model5 - Acc:17.42 % - Loss:2.2374235696792604 %
# Model4 - Acc:17.38 % - Loss:2.245886975288391 %
# Model6 - Acc:18.06 % - Loss:2.24117360830307 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=3 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 4/20] ✓  time=70.65s  cumulative=293.25s
#   [Epoch 5/20] threads started …
# Agent 5 start
# Agent 2 start
# Agent 4 start
# Agent 1 start
# Agent 3 start
# Agent 8 start
# Agent 9 start
# Agent 0 start
# Agent 7 start
# Agent 6 start
# Model5 - Acc:23.34 % - Loss:2.0875084364414214 %
# Model2 - Acc:23.0 % - Loss:2.083712311029434 %
# Model4 - Acc:23.36 % - Loss:2.0867241220474244 %
# Model3 - Acc:23.04 % - Loss:2.079371280193329 %
# Model1 - Acc:23.04 % - Loss:2.09567401266098 %
# Model8 - Acc:22.08 % - Loss:2.0910996334552765 %
# Model9 - Acc:22.08 % - Loss:2.0810543789863587 %
# Model0 - Acc:23.02 % - Loss:2.0729213976860046 %
# Model7 - Acc:22.3 % - Loss:2.089188976049423 %
# Model6 - Acc:22.68 % - Loss:2.0917685277462006 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=4 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 5/20] ✓  time=76.01s  cumulative=369.26s
#   [Epoch 6/20] threads started …
# Agent 7 start
# Agent 4 start
# Agent 5 start
# Agent 6 start
# Agent 8 start
# Agent 1 start
# Agent 0 start
# Agent 2 start
# Agent 3 start
# Model7 - Acc:26.38 % - Loss:1.9807260630130767 %
# Agent 9 start
# Model4 - Acc:28.04 % - Loss:1.9747824912071228 %
# Model5 - Acc:27.32 % - Loss:1.9788648517131806 %
# Model6 - Acc:26.6 % - Loss:1.9882842724323273 %
# Model8 - Acc:26.62 % - Loss:1.9910610580444337 %
# Model1 - Acc:26.32 % - Loss:2.002535829305649 %
# Model0 - Acc:26.42 % - Loss:1.9742533588409423 %
# Model2 - Acc:27.56 % - Loss:1.977118430376053 %
# Model3 - Acc:27.24 % - Loss:1.9747928967475892 %
# Model9 - Acc:26.46 % - Loss:1.9748049800395966 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=5 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 6/20] ✓  time=70.25s  cumulative=439.50s
#   [Epoch 7/20] threads started …
# Agent 0 start
# Agent 6 start
# Agent 5 start
# Agent 8 start
# Agent 7 start
# Agent 2 start
# Agent 3 start
# Agent 1 start
# Agent 4 start
# Agent 9 start
# Model0 - Acc:29.66 % - Loss:1.9061625950336456 %
# Model6 - Acc:29.42 % - Loss:1.9248976566791534 %
# Model5 - Acc:29.9 % - Loss:1.9065179216861725 %
# Model8 - Acc:29.58 % - Loss:1.9197679197788238 %
# Model7 - Acc:29.2 % - Loss:1.908359246492386 %
# Model2 - Acc:30.04 % - Loss:1.9038719434738158 %
# Model3 - Acc:30.26 % - Loss:1.9121865859031677 %
# Model1 - Acc:29.28 % - Loss:1.9277941868305206 %
# Model4 - Acc:30.4 % - Loss:1.8988067622184754 %
# Model9 - Acc:30.18 % - Loss:1.9006179225444795 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=6 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 7/20] ✓  time=69.52s  cumulative=509.03s
#   [Epoch 8/20] threads started …
# Agent 8 start
# Agent 9 start
# Agent 2 start
# Agent 6 start
# Agent 0 start
# Agent 1 start
# Agent 7 start
# Agent 4 start
# Agent 5 start
# Agent 3 start
# Model8 - Acc:31.66 % - Loss:1.8459537150859833 %
# Model9 - Acc:32.42 % - Loss:1.83284947180748 %
# Model2 - Acc:31.86 % - Loss:1.8334532194137574 %
# Model6 - Acc:31.86 % - Loss:1.862097356081009 %
# Model0 - Acc:31.74 % - Loss:1.835302796125412 %
# Model1 - Acc:31.36 % - Loss:1.855100443124771 %
# Model7 - Acc:31.68 % - Loss:1.8367968828678132 %
# Model4 - Acc:31.98 % - Loss:1.8360165085792541 %
# Model5 - Acc:32.48 % - Loss:1.8331003482341766 %
# Model3 - Acc:31.8 % - Loss:1.8502144722938538 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=7 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 8/20] ✓  time=70.92s  cumulative=579.95s
#   [Epoch 9/20] threads started …
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Agent 5 start
# Agent 6 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Model3 - Acc:34.52 % - Loss:1.7772946119308473 %
# Model2 - Acc:33.9 % - Loss:1.7727554333209992 %
# Model4 - Acc:33.98 % - Loss:1.7719181911945343 %
# Model1 - Acc:33.08 % - Loss:1.7875905582904816 %
# Model9 - Acc:33.98 % - Loss:1.7647981703281403 %
# Model5 - Acc:34.8 % - Loss:1.767736965894699 %
# Model6 - Acc:33.56 % - Loss:1.7931895487308502 %
# Model0 - Acc:33.9 % - Loss:1.7719480876922606 %
# Model8 - Acc:33.3 % - Loss:1.7852457840442657 %
# Model7 - Acc:34.26 % - Loss:1.77515593957901 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=8 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 9/20] ✓  time=69.38s  cumulative=649.32s
#   [Epoch 10/20] threads started …
# Agent 5 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Agent 2 start
# Agent 1 start
# Agent 0 start
# Agent 7 start
# Agent 8 start
# Agent 9 start
# Model5 - Acc:36.78 % - Loss:1.7127616114616393 %
# Model3 - Acc:36.02 % - Loss:1.7306963968276978 %
# Model6 - Acc:35.86 % - Loss:1.7410505987405778 %
# Model4 - Acc:35.58 % - Loss:1.7217726037502288 %
# Model2 - Acc:36.3 % - Loss:1.7074199191331862 %
# Model1 - Acc:35.3 % - Loss:1.7288116734027863 %
# Model0 - Acc:35.74 % - Loss:1.7128507466316223 %
# Model7 - Acc:36.0 % - Loss:1.7164911029338836 %
# Model8 - Acc:35.66 % - Loss:1.7197682902812959 %
# Model9 - Acc:36.16 % - Loss:1.7157684971094131 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=9 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 10/20] ✓  time=67.94s  cumulative=717.27s
#   [Epoch 11/20] threads started …
# Agent 4 start
# Agent 3 start
# Agent 0 start
# Agent 6 start
# Agent 5 start
# Agent 1 start
# Agent 9 start
# Agent 7 start
# Agent 8 start
# Agent 2 start
# Model4 - Acc:37.84 % - Loss:1.6658855811357498 %
# Model0 - Acc:37.8 % - Loss:1.6594533126354218 %
# Model6 - Acc:36.7 % - Loss:1.6958103284835815 %
# Model5 - Acc:38.16 % - Loss:1.6610830729007722 %
# Model3 - Acc:37.78 % - Loss:1.6677856320142745 %
# Model7 - Acc:38.22 % - Loss:1.6716706782579422 %
# Model8 - Acc:38.18 % - Loss:1.668919713973999 %
# Model1 - Acc:37.94 % - Loss:1.6788009085655213 %
# Model9 - Acc:38.58 % - Loss:1.6552712777853011 %
# Model2 - Acc:38.36 % - Loss:1.6424869232177735 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=10 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 11/20] ✓  time=61.95s  cumulative=779.21s
#   [Epoch 12/20] threads started …
# Agent 9 start
# Agent 1 start
# Agent 7 start
# Agent 0 start
# Agent 5 start
# Agent 2 start
# Agent 6 start
# Agent 8 start
# Agent 3 start
# Agent 4 start
# Model9 - Acc:41.26 % - Loss:1.6022461549043656 %
# Model1 - Acc:39.38 % - Loss:1.6202717336416244 %
# Model7 - Acc:40.1 % - Loss:1.6154917056560516 %
# Model0 - Acc:39.38 % - Loss:1.6202627917528152 %
# Model2 - Acc:39.82 % - Loss:1.6089560743570328 %
# Model8 - Acc:40.14 % - Loss:1.625981803894043 %
# Model5 - Acc:40.04 % - Loss:1.6164348454475403 %
# Model6 - Acc:38.8 % - Loss:1.6521832734346389 %
# Model3 - Acc:39.32 % - Loss:1.625961466550827 %
# Model4 - Acc:39.4 % - Loss:1.6308677070140838 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=11 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 12/20] ✓  time=62.32s  cumulative=841.54s
#   [Epoch 13/20] threads started …
# Agent 1 start
# Agent 3 start
# Agent 2 start
# Agent 9 start
# Agent 4 start
# Agent 6 start
# Agent 7 start
# Agent 0 start
# Agent 8 start
# Agent 5 start
# Model1 - Acc:41.2 % - Loss:1.5861929022073746 %
# Model3 - Acc:40.86 % - Loss:1.6021752455234528 %
# Model2 - Acc:40.7 % - Loss:1.5801493294239044 %
# Model9 - Acc:41.92 % - Loss:1.574901199221611 %
# Model4 - Acc:41.2 % - Loss:1.6013694052696228 %
# Model6 - Acc:40.46 % - Loss:1.615022982954979 %
# Model7 - Acc:41.2 % - Loss:1.593190235376358 %
# Model0 - Acc:41.64 % - Loss:1.5895328524112702 %
# Model8 - Acc:41.18 % - Loss:1.5959305688142778 %
# Model5 - Acc:41.68 % - Loss:1.5954482749700547 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=12 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 13/20] ✓  time=61.98s  cumulative=903.51s
#   [Epoch 14/20] threads started …
# Agent 3 start
# Agent 4 start
# Agent 8 start
# Agent 5 start
# Agent 6 start
# Agent 2 start
# Agent 0 start
# Agent 9 start
# Agent 7 start
# Agent 1 start
# Model3 - Acc:42.52 % - Loss:1.5656713645458222 %
# Model4 - Acc:42.54 % - Loss:1.5717587014436722 %
# Model5 - Acc:42.84 % - Loss:1.5648605606555939 %
# Model6 - Acc:41.06 % - Loss:1.5896243295669557 %
# Model8 - Acc:42.5 % - Loss:1.5738986625671387 %
# Model2 - Acc:42.04 % - Loss:1.5495630667209626 %
# Model0 - Acc:42.38 % - Loss:1.5718925521373748 %
# Model9 - Acc:43.74 % - Loss:1.54065265583992 %
# Model7 - Acc:42.78 % - Loss:1.5548403131961823 %
# Model1 - Acc:41.46 % - Loss:1.563781121969223 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=13 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 14/20] ✓  time=59.90s  cumulative=963.41s
#   [Epoch 15/20] threads started …
# Agent 0 start
# Agent 6 start
# Agent 3 start
# Agent 9 start
# Agent 4 start
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 5 start
# Agent 2 start
# Model0 - Acc:42.02 % - Loss:1.5506572604179383 %
# Model6 - Acc:42.52 % - Loss:1.5683699741363526 %
# Model8 - Acc:43.74 % - Loss:1.5357950452566147 %
# Model7 - Acc:43.46 % - Loss:1.5339354827404021 %
# Model5 - Acc:43.56 % - Loss:1.541963393807411 %
# Model3 - Acc:42.64 % - Loss:1.5404351714849471 %
# Model9 - Acc:44.42 % - Loss:1.5206137064695358 %
# Model4 - Acc:42.84 % - Loss:1.5524348009824753 %
# Model1 - Acc:42.4 % - Loss:1.551451952457428 %
# Model2 - Acc:42.7 % - Loss:1.5314999428987504 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=14 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 15/20] ✓  time=59.50s  cumulative=1022.91s
#   [Epoch 16/20] threads started …
# Agent 2 start
# Agent 1 start
# Agent 0 start
# Agent 4 start
# Agent 8 start
# Agent 7 start
# Agent 6 start
# Agent 9 start
# Agent 5 start
# Model2 - Acc:43.1 % - Loss:1.5103527250289916 %
# Model1 - Acc:43.74 % - Loss:1.5263885678052902 %
# Agent 3 start
# Model0 - Acc:43.8 % - Loss:1.5323850132226944 %
# Model8 - Acc:44.44 % - Loss:1.5148391857147216 %
# Model7 - Acc:44.4 % - Loss:1.5147972666025162 %
# Model9 - Acc:45.3 % - Loss:1.4872534768581391 %
# Model4 - Acc:43.84 % - Loss:1.5310398695468903 %
# Model6 - Acc:43.84 % - Loss:1.5449937473535538 %
# Model5 - Acc:44.42 % - Loss:1.5340951364040374 %
# Model3 - Acc:43.96 % - Loss:1.5157334377765657 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=15 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 16/20] ✓  time=62.09s  cumulative=1084.99s
#   [Epoch 17/20] threads started …
# Agent 4 start
# Agent 2 start
# Agent 9 start
# Agent 3 start
# Agent 1 start
# Agent 0 start
# Agent 7 start
# Agent 5 start
# Agent 8 start
# Agent 6 start
# Model4 - Acc:45.22 % - Loss:1.5002617381811143 %
# Model2 - Acc:44.58 % - Loss:1.4935762193202973 %
# Model9 - Acc:46.78 % - Loss:1.4547560753822326 %
# Model3 - Acc:44.84 % - Loss:1.4971331226825715 %
# Model1 - Acc:44.44 % - Loss:1.5090182521343232 %
# Model0 - Acc:44.16 % - Loss:1.5117416077852248 %
# Model7 - Acc:44.78 % - Loss:1.4971974084377289 %
# Model5 - Acc:44.5 % - Loss:1.508479552268982 %
# Model8 - Acc:45.14 % - Loss:1.4978954467773438 %
# Model6 - Acc:43.74 % - Loss:1.53425845515728 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=16 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 17/20] ✓  time=65.21s  cumulative=1150.20s
#   [Epoch 18/20] threads started …
# Agent 6 start
# Agent 8 start
# Agent 4 start
# Agent 9 start
# Agent 1 start
# Agent 5 start
# Agent 3 start
# Agent 2 start
# Model6 - Acc:44.96 % - Loss:1.5115442699193955 %
# Agent 0 start
# Agent 7 start
# Model4 - Acc:45.12 % - Loss:1.4940474874973297 %
# Model5 - Acc:46.16 % - Loss:1.4913169659376144 %
# Model8 - Acc:45.92 % - Loss:1.4858403943777085 %
# Model9 - Acc:47.04 % - Loss:1.4319312232732773 %
# Model3 - Acc:45.86 % - Loss:1.4753205206394195 %
# Model1 - Acc:45.1 % - Loss:1.4969079706668853 %
# Model7 - Acc:45.28 % - Loss:1.4834827300310134 %
# Model2 - Acc:45.26 % - Loss:1.4852970945835113 %
# Model0 - Acc:45.0 % - Loss:1.4988705124855042 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=17 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 18/20] ✓  time=64.20s  cumulative=1214.41s
#   [Epoch 19/20] threads started …
# Agent 5 start
# Agent 7 start
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 6 start
# Agent 8 start
# Agent 0 start
# Agent 9 start
# Agent 1 start
# Model5 - Acc:46.4 % - Loss:1.4787579679489136 %
# Model7 - Acc:46.72 % - Loss:1.4661333014965057 %
# Model4 - Acc:46.0 % - Loss:1.4828130209445953 %
# Model6 - Acc:45.46 % - Loss:1.4878289604187012 %
# Model2 - Acc:45.66 % - Loss:1.460291139960289 %
# Model3 - Acc:46.54 % - Loss:1.4634829041957855 %
# Model8 - Acc:47.12 % - Loss:1.4698100363016129 %
# Model0 - Acc:45.86 % - Loss:1.486648561835289 %
# Model9 - Acc:47.78 % - Loss:1.4131803959608078 %
# Model1 - Acc:45.78 % - Loss:1.4761164395809174 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=18 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 19/20] ✓  time=62.92s  cumulative=1277.32s
#   [Epoch 20/20] threads started …
# Agent 2 start
# Agent 8 start
# Agent 0 start
# Agent 1 start
# Agent 9 start
# Agent 7 start
# Agent 5 start
# Agent 3 start
# Agent 6 start
# Agent 4 start
# Model2 - Acc:46.64 % - Loss:1.4589900357723236 %
# Model8 - Acc:47.84 % - Loss:1.4462931150197982 %
# Model0 - Acc:46.72 % - Loss:1.4718639911413194 %
# Model9 - Acc:48.66 % - Loss:1.3842249903678894 %
# Model1 - Acc:46.3 % - Loss:1.4612983750104904 %
# Model7 - Acc:47.0 % - Loss:1.453295575737953 %
# Model5 - Acc:46.86 % - Loss:1.458857956647873 %
# Model3 - Acc:47.5 % - Loss:1.445458166360855 %
# Model6 - Acc:45.5 % - Loss:1.487987525701523 %
# Model4 - Acc:46.26 % - Loss:1.4674971473217011 %
# [DEBUG] set_epoch_messages called → 90 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
# [DEBUG] _record epoch=19 → n_messages=90
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 90
#   [Epoch 20/20] ✓  time=58.21s  cumulative=1335.53s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=20 | total=1335.53s | mean=66.78s/ep | fastest=ep20(58.21s) | slowest=ep1(76.74s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_connected_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 48.03%
#   Val Loss  finale : 1.4210
#   Temps total      : 1335.53s
#   Temps moyen/ép.  : 66.78s
#   Époque la + rapide : ép.20 (58.21s)
#   Époque la + lente  : ép.1 (76.74s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 425.761 MB
#     Total messages    : 1,800
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 153.22 ms
#     Synchro totale    : 3064.3 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 425.761 MB
#     Total messages    : 1,800
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 153.22 ms
#     Synchro totale    : 3064.3 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ============================================================
#   RUN — méthode : Sequential_AC_cycle_graph
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/20] threads started …
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 6 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 5 start
# Agent 8 start
# Agent 7 start
# Model4 - Acc:9.78 % - Loss:2.3035706510543825 %
# Model2 - Acc:10.82 % - Loss:2.300431394100189 %
# Model3 - Acc:10.82 % - Loss:2.3023310794830323 %
# Model1 - Acc:10.02 % - Loss:2.303054108142853 %
# Model6 - Acc:12.62 % - Loss:2.2998511786460876 %
# Model9 - Acc:11.12 % - Loss:2.299295040130615 %
# Model0 - Acc:10.98 % - Loss:2.2996043133735657 %
# Model5 - Acc:13.0 % - Loss:2.2996250100135804 %
# Model8 - Acc:10.08 % - Loss:2.3028662867546084 %
# Model7 - Acc:10.44 % - Loss:2.302369092941284 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=0 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 1/20] ✓  time=59.20s  cumulative=59.20s
#   [Epoch 2/20] threads started …
# Agent 4 start
# Agent 5 start
# Agent 3 start
# Agent 6 start
# Agent 1 start
# Agent 7 start
# Agent 2 start
# Agent 0 start
# Agent 8 start
# Agent 9 start
# Model4 - Acc:10.32 % - Loss:2.3024753518104553 %
# Model5 - Acc:10.32 % - Loss:2.3024788646698 %
# Model3 - Acc:10.42 % - Loss:2.3023690462112425 %
# Model6 - Acc:10.78 % - Loss:2.3022749814987185 %
# Model1 - Acc:10.54 % - Loss:2.3021442804336547 %
# Model7 - Acc:10.08 % - Loss:2.303037786960602 %
# Model2 - Acc:9.8 % - Loss:2.3028415002822875 %
# Model0 - Acc:11.04 % - Loss:2.301747270107269 %
# Model8 - Acc:10.54 % - Loss:2.3022417645454407 %
# Model9 - Acc:11.76 % - Loss:2.3001939644813536 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=1 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 2/20] ✓  time=64.12s  cumulative=123.33s
#   [Epoch 3/20] threads started …
# Agent 0 start
# Agent 8 start
# Agent 5 start
# Agent 6 start
# Agent 7 start
# Agent 2 start
# Agent 3 start
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Model0 - Acc:12.56 % - Loss:2.29966849899292 %
# Model8 - Acc:14.52 % - Loss:2.301085469722748 %
# Model5 - Acc:9.5 % - Loss:2.3025307841300964 %
# Model6 - Acc:10.82 % - Loss:2.3024024567604067 %
# Model7 - Acc:10.66 % - Loss:2.3027756924629212 %
# Model2 - Acc:9.76 % - Loss:2.3027744345664978 %
# Model3 - Acc:10.38 % - Loss:2.30232403755188 %
# Model4 - Acc:10.24 % - Loss:2.302401755332947 %
# Model1 - Acc:10.68 % - Loss:2.3022711443901063 %
# Model9 - Acc:10.84 % - Loss:2.2986092896461487 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=2 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 3/20] ✓  time=56.14s  cumulative=179.47s
#   [Epoch 4/20] threads started …
# Agent 8 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 2 start
# Agent 7 start
# Agent 3 start
# Agent 4 start
# Agent 5 start
# Agent 6 start
# Model8 - Acc:13.2 % - Loss:2.295784823894501 %
# Model1 - Acc:11.06 % - Loss:2.3022181062698364 %
# Model0 - Acc:13.62 % - Loss:2.292052538871765 %
# Model9 - Acc:12.92 % - Loss:2.2904934792518614 %
# Model2 - Acc:9.96 % - Loss:2.302821892261505 %
# Model7 - Acc:11.02 % - Loss:2.3023193678855898 %
# Model3 - Acc:10.38 % - Loss:2.302277103424072 %
# Model4 - Acc:10.04 % - Loss:2.3023465151786806 %
# Model5 - Acc:9.72 % - Loss:2.302516605377197 %
# Model6 - Acc:9.96 % - Loss:2.3024543623924254 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=3 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 4/20] ✓  time=57.09s  cumulative=236.56s
#   [Epoch 5/20] threads started …
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 3 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Agent 6 start
# Agent 5 start
# Model4 - Acc:10.16 % - Loss:2.3024851875305177 %
# Model1 - Acc:11.06 % - Loss:2.302073543548584 %
# Model9 - Acc:14.44 % - Loss:2.2483170580863954 %
# Model2 - Acc:9.92 % - Loss:2.3028648738861084 %
# Model3 - Acc:10.32 % - Loss:2.3022727570533754 %
# Model0 - Acc:14.66 % - Loss:2.2497962238788607 %
# Model8 - Acc:15.72 % - Loss:2.250075518608093 %
# Model7 - Acc:14.74 % - Loss:2.2963522758483887 %
# Model6 - Acc:10.86 % - Loss:2.3023716659545896 %
# Model5 - Acc:9.96 % - Loss:2.3025089702606203 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=4 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 5/20] ✓  time=58.57s  cumulative=295.13s
#   [Epoch 6/20] threads started …
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 7 start
# Agent 6 start
# Agent 9 start
# Agent 8 start
# Agent 1 start
# Agent 0 start
# Model5 - Acc:10.28 % - Loss:2.3025174884796145 %
# Model4 - Acc:10.32 % - Loss:2.3024824147224425 %
# Model2 - Acc:10.06 % - Loss:2.30282386302948 %
# Model3 - Acc:10.1 % - Loss:2.3022220501899717 %
# Model7 - Acc:16.38 % - Loss:2.217955936908722 %
# Model6 - Acc:12.2 % - Loss:2.299425421714783 %
# Model9 - Acc:18.32 % - Loss:2.1978674340248108 %
# Model8 - Acc:18.36 % - Loss:2.185920527219772 %
# Model1 - Acc:10.94 % - Loss:2.301162416934967 %
# Model0 - Acc:18.08 % - Loss:2.199705946445465 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=5 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 6/20] ✓  time=58.39s  cumulative=353.52s
#   [Epoch 7/20] threads started …
# Agent 5 start
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Agent 9 start
# Agent 1 start
# Agent 0 start
# Agent 8 start
# Agent 3 start
# Agent 2 start
# Model5 - Acc:10.82 % - Loss:2.301724154472351 %
# Model6 - Acc:17.26 % - Loss:2.2006102819442748 %
# Model4 - Acc:10.46 % - Loss:2.302440640926361 %
# Model7 - Acc:18.12 % - Loss:2.147211218595505 %
# Model9 - Acc:19.88 % - Loss:2.1547916457653047 %
# Model1 - Acc:13.52 % - Loss:2.296483775138855 %
# Model0 - Acc:19.56 % - Loss:2.15745440530777 %
# Model8 - Acc:21.12 % - Loss:2.140162483215332 %
# Model3 - Acc:10.58 % - Loss:2.302222635269165 %
# Model2 - Acc:9.82 % - Loss:2.302843068122864 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=6 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 7/20] ✓  time=58.79s  cumulative=412.31s
#   [Epoch 8/20] threads started …
# Agent 0 start
# Agent 9 start
# Agent 8 start
# Agent 1 start
# Agent 3 start
# Agent 7 start
# Agent 6 start
# Agent 2 start
# Agent 4 start
# Agent 5 start
# Model0 - Acc:21.14 % - Loss:2.129299032211304 %
# Model9 - Acc:21.0 % - Loss:2.125030886411667 %
# Model8 - Acc:23.04 % - Loss:2.109926328420639 %
# Model3 - Acc:10.44 % - Loss:2.3021992917060854 %
# Model1 - Acc:15.98 % - Loss:2.2615658185482026 %
# Model7 - Acc:21.0 % - Loss:2.107095778465271 %
# Model6 - Acc:20.58 % - Loss:2.129007935285568 %
# Model2 - Acc:10.32 % - Loss:2.30279362821579 %
# Model4 - Acc:10.44 % - Loss:2.3021922731399536 %
# Model5 - Acc:17.26 % - Loss:2.205149626016617 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=7 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 8/20] ✓  time=57.80s  cumulative=470.11s
#   [Epoch 9/20] threads started …
# Agent 0 start
# Agent 3 start
# Agent 2 start
# Agent 6 start
# Agent 8 start
# Agent 1 start
# Agent 9 start
# Model0 - Acc:22.1 % - Loss:2.1008750364780426 %
# Agent 5 start
# Agent 7 start
# Agent 4 start
# Model3 - Acc:9.92 % - Loss:2.3020684089660644 %
# Model2 - Acc:10.32 % - Loss:2.3027007718086243 %
# Model8 - Acc:23.32 % - Loss:2.0855010430812837 %
# Model1 - Acc:17.48 % - Loss:2.2120038583278654 %
# Model9 - Acc:21.48 % - Loss:2.0998861291408537 %
# Model6 - Acc:23.48 % - Loss:2.0853681149482726 %
# Model5 - Acc:20.84 % - Loss:2.1255883855819704 %
# Model7 - Acc:22.78 % - Loss:2.073382829427719 %
# Model4 - Acc:18.02 % - Loss:2.208924409151077 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=8 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 9/20] ✓  time=60.12s  cumulative=530.22s
#   [Epoch 10/20] threads started …
# Agent 2 start
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Agent 6 start
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 0 start
# Agent 9 start
# Model2 - Acc:10.98 % - Loss:2.3007536787986753 %
# Model3 - Acc:17.94 % - Loss:2.210270557880402 %
# Model5 - Acc:22.92 % - Loss:2.07768079829216 %
# Model4 - Acc:21.22 % - Loss:2.128325903892517 %
# Model6 - Acc:23.96 % - Loss:2.0510030994415285 %
# Model8 - Acc:24.78 % - Loss:2.064837342977524 %
# Model1 - Acc:18.28 % - Loss:2.1789947037696837 %
# Model7 - Acc:24.04 % - Loss:2.045406155586243 %
# Model0 - Acc:22.78 % - Loss:2.0776803855895998 %
# Model9 - Acc:22.88 % - Loss:2.074876872777939 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=9 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 10/20] ✓  time=65.03s  cumulative=595.25s
#   [Epoch 11/20] threads started …
# Agent 6 start
# Agent 4 start
# Agent 5 start
# Agent 7 start
# Agent 2 start
# Agent 1 start
# Agent 8 start
# Agent 9 start
# Agent 3 start
# Agent 0 start
# Model6 - Acc:24.94 % - Loss:2.0198162083625792 %
# Model4 - Acc:22.62 % - Loss:2.07943527340889 %
# Model5 - Acc:24.06 % - Loss:2.0363423335552215 %
# Model7 - Acc:24.54 % - Loss:2.0166174273490904 %
# Model2 - Acc:18.66 % - Loss:2.1675339703559877 %
# Model1 - Acc:20.64 % - Loss:2.1518111181259156 %
# Model8 - Acc:25.08 % - Loss:2.0428161296844483 %
# Model9 - Acc:23.14 % - Loss:2.051028771162033 %
# Model3 - Acc:20.88 % - Loss:2.1339541556835173 %
# Model0 - Acc:23.72 % - Loss:2.054316999197006 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=10 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 11/20] ✓  time=59.95s  cumulative=655.20s
#   [Epoch 12/20] threads started …
# Agent 7 start
# Agent 8 start
# Agent 1 start
# Agent 0 start
# Agent 6 start
# Agent 9 start
# Agent 2 start
# Agent 3 start
# Agent 5 start
# Agent 4 start
# Model7 - Acc:26.22 % - Loss:1.9808726434707642 %
# Model8 - Acc:26.24 % - Loss:2.0048058817386627 %
# Model1 - Acc:20.96 % - Loss:2.096747981071472 %
# Model0 - Acc:23.66 % - Loss:2.027923044681549 %
# Model6 - Acc:26.24 % - Loss:1.9855676720142363 %
# Model9 - Acc:24.9 % - Loss:2.018252450466156 %
# Model2 - Acc:20.92 % - Loss:2.1085039427280425 %
# Model3 - Acc:22.24 % - Loss:2.0732376465797424 %
# Model5 - Acc:25.86 % - Loss:1.9901678795814515 %
# Model4 - Acc:24.2 % - Loss:2.0270381836891174 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=11 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 12/20] ✓  time=58.34s  cumulative=713.54s
#   [Epoch 13/20] threads started …
# Agent 9 start
# Agent 0 start
# Agent 3 start
# Agent 1 start
# Agent 8 start
# Agent 6 start
# Agent 5 start
# Agent 7 start
# Agent 4 start
# Agent 2 start
# Model9 - Acc:26.0 % - Loss:1.9855504887104034 %
# Model0 - Acc:26.88 % - Loss:1.9911433506011962 %
# Model3 - Acc:24.18 % - Loss:2.008275002002716 %
# Model1 - Acc:22.76 % - Loss:2.0452692403793336 %
# Model8 - Acc:26.78 % - Loss:1.9688451471328736 %
# Model6 - Acc:28.76 % - Loss:1.9319371964931489 %
# Model5 - Acc:27.4 % - Loss:1.938521279335022 %
# Model7 - Acc:27.82 % - Loss:1.9388815519809723 %
# Model2 - Acc:22.6 % - Loss:2.054528487443924 %
# Model4 - Acc:26.82 % - Loss:1.973671471118927 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=12 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 13/20] ✓  time=56.50s  cumulative=770.04s
#   [Epoch 14/20] threads started …
# Agent 2 start
# Agent 3 start
# Agent 4 start
# Agent 8 start
# Agent 5 start
# Agent 9 start
# Agent 7 start
# Agent 1 start
# Agent 0 start
# Agent 6 start
# Model2 - Acc:25.0 % - Loss:1.9956332371234893 %
# Model3 - Acc:27.62 % - Loss:1.9413710181713104 %
# Model4 - Acc:29.68 % - Loss:1.897533630847931 %
# Model5 - Acc:29.76 % - Loss:1.856151742219925 %
# Model8 - Acc:28.16 % - Loss:1.9109809563159943 %
# Model9 - Acc:27.28 % - Loss:1.9330882437229155 %
# Model7 - Acc:29.86 % - Loss:1.8762022643089293 %
# Model1 - Acc:25.48 % - Loss:1.9820041592121125 %
# Model0 - Acc:27.12 % - Loss:1.9464899790287018 %
# Model6 - Acc:30.78 % - Loss:1.8561825850009919 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=13 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 14/20] ✓  time=64.70s  cumulative=834.75s
#   [Epoch 15/20] threads started …
# Agent 7 start
# Agent 6 start
# Agent 2 start
# Agent 4 start
# Agent 1 start
# Agent 0 start
# Agent 9 start
# Agent 5 start
# Agent 8 start
# Agent 3 start
# Model7 - Acc:30.7 % - Loss:1.8295285551548004 %
# Model6 - Acc:32.04 % - Loss:1.813022626876831 %
# Model4 - Acc:30.16 % - Loss:1.834369055747986 %
# Model2 - Acc:28.2 % - Loss:1.909833566904068 %
# Model1 - Acc:27.6 % - Loss:1.904227608680725 %
# Model0 - Acc:29.08 % - Loss:1.873027591228485 %
# Model5 - Acc:30.78 % - Loss:1.8102215831279755 %
# Model9 - Acc:29.28 % - Loss:1.8655994975566863 %
# Model8 - Acc:29.3 % - Loss:1.8588040874004363 %
# Model3 - Acc:29.64 % - Loss:1.8621674118041993 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=14 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 15/20] ✓  time=59.91s  cumulative=894.66s
#   [Epoch 16/20] threads started …
# Agent 6 start
# Agent 8 start
# Agent 1 start
# Agent 7 start
# Agent 4 start
# Agent 9 start
# Agent 5 start
# Agent 0 start
# Agent 3 start
# Agent 2 start
# Model6 - Acc:33.62 % - Loss:1.7756710889339447 %
# Model8 - Acc:30.0 % - Loss:1.8223808121681213 %
# Model1 - Acc:30.84 % - Loss:1.8204927494525909 %
# Model7 - Acc:32.1 % - Loss:1.802234384059906 %
# Model4 - Acc:32.76 % - Loss:1.785885424375534 %
# Model9 - Acc:31.18 % - Loss:1.826218692779541 %
# Model5 - Acc:31.74 % - Loss:1.774853282213211 %
# Model0 - Acc:30.06 % - Loss:1.8231927478313446 %
# Model3 - Acc:31.22 % - Loss:1.8118758060932159 %
# Model2 - Acc:30.88 % - Loss:1.8406096189022063 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=15 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 16/20] ✓  time=57.16s  cumulative=951.82s
#   [Epoch 17/20] threads started …
# Agent 1 start
# Agent 9 start
# Agent 7 start
# Agent 0 start
# Agent 8 start
# Agent 6 start
# Agent 4 start
# Agent 3 start
# Agent 5 start
# Agent 2 start
# Model1 - Acc:33.22 % - Loss:1.7682705906629563 %
# Model9 - Acc:32.82 % - Loss:1.795137027144432 %
# Model7 - Acc:33.02 % - Loss:1.775517834663391 %
# Model0 - Acc:32.12 % - Loss:1.7868528137207031 %
# Model8 - Acc:32.02 % - Loss:1.8055405914783478 %
# Model6 - Acc:34.78 % - Loss:1.748625360250473 %
# Model4 - Acc:34.3 % - Loss:1.7521804671287537 %
# Model3 - Acc:33.28 % - Loss:1.7718125102519988 %
# Model5 - Acc:33.78 % - Loss:1.7438730776309967 %
# Model2 - Acc:32.74 % - Loss:1.783911150932312 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=16 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 17/20] ✓  time=62.58s  cumulative=1014.40s
#   [Epoch 18/20] threads started …
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 0 start
# Agent 3 start
# Agent 4 start
# Agent 6 start
# Agent 7 start
# Agent 5 start
# Model1 - Acc:34.58 % - Loss:1.7292327456474303 %
# Agent 8 start
# Model9 - Acc:34.08 % - Loss:1.7706052942276 %
# Model2 - Acc:35.02 % - Loss:1.7494697711467744 %
# Model0 - Acc:34.2 % - Loss:1.7504294574260713 %
# Model3 - Acc:34.74 % - Loss:1.729552524328232 %
# Model8 - Acc:33.6 % - Loss:1.768386360168457 %
# Model4 - Acc:35.66 % - Loss:1.7161435146331787 %
# Model6 - Acc:35.42 % - Loss:1.71620778632164 %
# Model7 - Acc:34.6 % - Loss:1.7503072488307954 %
# Model5 - Acc:35.14 % - Loss:1.7163622555732727 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=17 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 18/20] ✓  time=59.59s  cumulative=1073.99s
#   [Epoch 19/20] threads started …
# Agent 4 start
# Agent 2 start
# Agent 5 start
# Agent 3 start
# Agent 7 start
# Agent 0 start
# Agent 9 start
# Agent 6 start
# Agent 8 start
# Agent 1 start
# Model4 - Acc:36.9 % - Loss:1.682526044845581 %
# Model2 - Acc:36.44 % - Loss:1.7152681093215942 %
# Model5 - Acc:37.3 % - Loss:1.684128963470459 %
# Model3 - Acc:36.12 % - Loss:1.7021764698028565 %
# Model7 - Acc:35.46 % - Loss:1.7216828989982604 %
# Model0 - Acc:35.48 % - Loss:1.7175344383716584 %
# Model9 - Acc:34.34 % - Loss:1.7333680062294006 %
# Model6 - Acc:36.98 % - Loss:1.6922881803512573 %
# Model8 - Acc:34.7 % - Loss:1.748454768180847 %
# Model1 - Acc:36.24 % - Loss:1.69515110039711 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=18 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 19/20] ✓  time=63.26s  cumulative=1137.25s
#   [Epoch 20/20] threads started …
# Agent 7 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Agent 0 start
# Agent 1 start
# Agent 9 start
# Agent 8 start
# Agent 3 start
# Agent 2 start
# Model7 - Acc:36.98 % - Loss:1.6908206162452697 %
# Model4 - Acc:38.64 % - Loss:1.6591725639104844 %
# Model6 - Acc:37.64 % - Loss:1.6633200113773345 %
# Model5 - Acc:37.74 % - Loss:1.6528470752239228 %
# Model0 - Acc:37.34 % - Loss:1.684395308494568 %
# Model1 - Acc:38.02 % - Loss:1.6669116191864013 %
# Model9 - Acc:36.32 % - Loss:1.6911527798175812 %
# Model8 - Acc:36.96 % - Loss:1.7155768218040466 %
# Model3 - Acc:37.66 % - Loss:1.6620163431167603 %
# Model2 - Acc:38.84 % - Loss:1.6771656087636948 %
# [DEBUG] set_epoch_messages called → 20 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
# [DEBUG] _record epoch=19 → n_messages=20
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 20
#   [Epoch 20/20] ✓  time=53.33s  cumulative=1190.58s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=20 | total=1190.58s | mean=59.53s/ep | fastest=ep20(53.33s) | slowest=ep10(65.03s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_cycle_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 37.55%
#   Val Loss  finale : 1.6749
#   Temps total      : 1190.58s
#   Temps moyen/ép.  : 59.53s
#   Époque la + rapide : ép.20 (53.33s)
#   Époque la + lente  : ép.10 (65.03s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_cycle_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 94.614 MB
#     Total messages    : 400
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 33.33 ms
#     Synchro totale    : 666.5 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_cycle_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 94.614 MB
#     Total messages    : 400
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 33.33 ms
#     Synchro totale    : 666.5 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ============================================================
#   RUN — méthode : Sequential_AC_graph
# ============================================================
# 0
# Train size: 50000, Splits: [5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555, 5555], Sum: 55550
#   [Epoch 1/20] threads started …
# Agent 0 start
# Agent 1 start
# Agent 6 start
# Agent 9 start
# Agent 7 start
# Agent 8 start
# Agent 2 start
# Agent 4 start
# Agent 5 start
# Agent 3 start
# Model0 - Acc:11.28 % - Loss:2.301449828624725 %
# Model1 - Acc:9.96 % - Loss:2.301128935813904 %
# Model6 - Acc:11.48 % - Loss:2.3024536123275756 %
# Model9 - Acc:10.24 % - Loss:2.3028115425109865 %
# Model7 - Acc:10.2 % - Loss:2.3004076437950136 %
# Model8 - Acc:13.06 % - Loss:2.3015480270385744 %
# Model2 - Acc:10.9 % - Loss:2.3010347952842714 %
# Model4 - Acc:10.5 % - Loss:2.3037475981712343 %
# Model5 - Acc:11.46 % - Loss:2.299386672973633 %
# Model3 - Acc:11.34 % - Loss:2.3014390568733214 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=0 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 1/20] ✓  time=54.98s  cumulative=54.98s
#   [Epoch 2/20] threads started …
# Agent 2 start
# Agent 3 start
# Agent 1 start
# Agent 8 start
# Agent 0 start
# Agent 9 start
# Agent 5 start
# Agent 6 start
# Agent 4 start
# Agent 7 start
# Model2 - Acc:10.18 % - Loss:2.3025216403007507 %
# Model3 - Acc:11.34 % - Loss:2.301762125492096 %
# Model1 - Acc:10.7 % - Loss:2.3025542907714844 %
# Model8 - Acc:10.8 % - Loss:2.3020749044418336 %
# Model0 - Acc:9.86 % - Loss:2.302675320625305 %
# Model9 - Acc:12.26 % - Loss:2.301666470527649 %
# Model5 - Acc:10.3 % - Loss:2.301508728504181 %
# Model6 - Acc:10.08 % - Loss:2.3025495433807373 %
# Model4 - Acc:9.44 % - Loss:2.303070704936981 %
# Model7 - Acc:10.14 % - Loss:2.3019986066818237 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=1 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 2/20] ✓  time=53.80s  cumulative=108.78s
#   [Epoch 3/20] threads started …
# Agent 5 start
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 1 start
# Agent 0 start
# Agent 6 start
# Agent 7 start
# Agent 9 start
# Agent 8 start
# Model5 - Acc:11.06 % - Loss:2.3016224365234375 %
# Model4 - Acc:9.58 % - Loss:2.3029802951812743 %
# Model2 - Acc:9.64 % - Loss:2.302771070480347 %
# Model3 - Acc:11.34 % - Loss:2.301756965637207 %
# Model1 - Acc:10.54 % - Loss:2.3026561665534975 %
# Model0 - Acc:10.04 % - Loss:2.302642937660217 %
# Model7 - Acc:10.18 % - Loss:2.3026169939041137 %
# Model9 - Acc:11.26 % - Loss:2.3017004933357237 %
# Model6 - Acc:9.44 % - Loss:2.3027471799850465 %
# Model8 - Acc:10.58 % - Loss:2.3023115973472597 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=2 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 3/20] ✓  time=60.31s  cumulative=169.08s
#   [Epoch 4/20] threads started …
# Agent 7 start
# Agent 4 start
# Agent 5 start
# Agent 6 start
# Agent 9 start
# Agent 0 start
# Agent 1 start
# Agent 2 start
# Agent 3 start
# Agent 8 start
# Model7 - Acc:10.3 % - Loss:2.302585394382477 %
# Model4 - Acc:9.56 % - Loss:2.302856418132782 %
# Model5 - Acc:10.88 % - Loss:2.301594405174255 %
# Model6 - Acc:10.16 % - Loss:2.3026163201332093 %
# Model9 - Acc:10.54 % - Loss:2.3016510376930235 %
# Model0 - Acc:10.22 % - Loss:2.30244792842865 %
# Model1 - Acc:10.28 % - Loss:2.302583152294159 %
# Model2 - Acc:10.08 % - Loss:2.3026639051437376 %
# Model3 - Acc:11.02 % - Loss:2.301659924030304 %
# Model8 - Acc:10.22 % - Loss:2.302266860485077 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=3 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 4/20] ✓  time=58.28s  cumulative=227.36s
#   [Epoch 5/20] threads started …
# Agent 9 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Agent 1 start
# Agent 6 start
# Agent 3 start
# Agent 2 start
# Agent 5 start
# Agent 4 start
# Model9 - Acc:12.9 % - Loss:2.30134832572937 %
# Model0 - Acc:10.04 % - Loss:2.3021346664428712 %
# Model8 - Acc:10.26 % - Loss:2.30208616065979 %
# Model7 - Acc:10.62 % - Loss:2.3023232293128966 %
# Model1 - Acc:10.7 % - Loss:2.3021992273330687 %
# Model6 - Acc:10.48 % - Loss:2.302305184364319 %
# Model3 - Acc:11.34 % - Loss:2.3014461665153503 %
# Model2 - Acc:10.22 % - Loss:2.302435723781586 %
# Model5 - Acc:10.84 % - Loss:2.3014124536514284 %
# Model4 - Acc:10.28 % - Loss:2.302576662063599 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=4 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 5/20] ✓  time=59.13s  cumulative=286.49s
#   [Epoch 6/20] threads started …
# Agent 7 start
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 0 start
# Agent 1 start
# Agent 8 start
# Agent 9 start
# Agent 5 start
# Agent 6 start
# Model3 - Acc:11.22 % - Loss:2.300862094402313 %
# Model7 - Acc:10.66 % - Loss:2.301700809955597 %
# Model2 - Acc:11.28 % - Loss:2.3018812322616578 %
# Model4 - Acc:10.64 % - Loss:2.302021969795227 %
# Model0 - Acc:11.14 % - Loss:2.301449372291565 %
# Model1 - Acc:10.84 % - Loss:2.3016056308746338 %
# Model8 - Acc:10.7 % - Loss:2.301502471446991 %
# Model9 - Acc:13.24 % - Loss:2.300742461681366 %
# Model5 - Acc:11.06 % - Loss:2.3007898302078247 %
# Model6 - Acc:10.8 % - Loss:2.3017866740226745 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=5 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 6/20] ✓  time=60.32s  cumulative=346.81s
#   [Epoch 7/20] threads started …
# Agent 9 start
# Agent 5 start
# Agent 2 start
# Agent 3 start
# Agent 1 start
# Agent 4 start
# Agent 6 start
# Agent 0 start
# Agent 7 start
# Agent 8 start
# Model5 - Acc:11.02 % - Loss:2.2993922662734985 %
# Model2 - Acc:12.1 % - Loss:2.300472117424011 %
# Model3 - Acc:14.44 % - Loss:2.2993579721450805 %
# Model4 - Acc:10.5 % - Loss:2.3007014389038085 %
# Model9 - Acc:13.3 % - Loss:2.2993015360832216 %
# Model1 - Acc:12.4 % - Loss:2.3002251710891723 %
# Model6 - Acc:14.28 % - Loss:2.3003736510276793 %
# Model0 - Acc:13.5 % - Loss:2.300065933704376 %
# Model7 - Acc:11.64 % - Loss:2.3002178750038147 %
# Model8 - Acc:10.74 % - Loss:2.3001318163871765 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=6 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 7/20] ✓  time=61.67s  cumulative=408.48s
# ...
# Agent 0 start
# Agent 7 start
# Model5 - Acc:25.12 % - Loss:2.012301025390625 %
# Model4 - Acc:24.74 % - Loss:2.0113023030757904 %
# Model6 - Acc:24.34 % - Loss:1.9918103539943695 %
# Model3 - Acc:24.66 % - Loss:2.00259011387825 %
# Model9 - Acc:24.92 % - Loss:1.9969476857185364 %
# Model8 - Acc:24.7 % - Loss:2.0033994655609133 %
# Model2 - Acc:23.96 % - Loss:2.001653121471405 %
# Model0 - Acc:24.6 % - Loss:2.0029921245574953 %
# Model1 - Acc:25.4 % - Loss:1.9875459470748902 %
# Model7 - Acc:23.9 % - Loss:2.0138686499595644 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=12 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 13/20] ✓  time=36.17s  cumulative=485.35s
#   [Epoch 14/20] threads started …
# Agent 7 start
# Agent 8 start
# Agent 0 start
# Agent 6 start
# Agent 5 start
# Agent 9 start
# Agent 4 start
# Agent 2 start
# Agent 3 start
# Agent 1 start
# Model7 - Acc:27.34 % - Loss:1.954631579875946 %
# Model8 - Acc:28.0 % - Loss:1.9498143084049224 %
# Model0 - Acc:26.7 % - Loss:1.9480520098209382 %
# Model6 - Acc:27.88 % - Loss:1.9315096130371094 %
# Model9 - Acc:26.74 % - Loss:1.941380040884018 %
# Model5 - Acc:26.4 % - Loss:1.9624032330513002 %
# Model4 - Acc:27.24 % - Loss:1.94763671541214 %
# Model2 - Acc:27.58 % - Loss:1.9320369296073914 %
# Model3 - Acc:27.9 % - Loss:1.9391731123924256 %
# Model1 - Acc:28.38 % - Loss:1.9273191089630126 %
# [DEBUG] set_epoch_messages called → 24 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 24
# [DEBUG] _record epoch=13 → n_messages=24
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 24
#   [Epoch 14/20] ✓  time=37.38s  cumulative=522.72s
#   [Epoch 15/20] threads started …
# Agent 9 start
# Agent 1 start
# Agent 8 start
# Agent 0 start
# Agent 7 start
# Agent 2 start
# Agent 3 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Model9 - Acc:28.98 % - Loss:1.8876100895404815 %
# Model1 - Acc:29.96 % - Loss:1.8776992905139922 %
# Model8 - Acc:30.56 % - Loss:1.8892394261360168 %
# Model0 - Acc:29.74 % - Loss:1.8831797828674317 %
# Model2 - Acc:31.0 % - Loss:1.8662911489009857 %
# Model7 - Acc:28.44 % - Loss:1.8911681795120239 %
# Model3 - Acc:30.44 % - Loss:1.8761303112506866 %
# Model4 - Acc:29.86 % - Loss:1.887428129196167 %
# Model6 - Acc:29.42 % - Loss:1.8735502212047577 %
# Model5 - Acc:28.6 % - Loss:1.9100383129119873 %
# [DEBUG] set_epoch_messages called → 36 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 36
# [DEBUG] _record epoch=14 → n_messages=36
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 36
#   [Epoch 15/20] ✓  time=36.46s  cumulative=559.19s
#   [Epoch 16/20] threads started …
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 4 start
# Agent 3 start
# Agent 8 start
# Agent 5 start
# Agent 0 start
# Agent 6 start
# Agent 7 start
# Model1 - Acc:31.9 % - Loss:1.8222346606254578 %
# Model2 - Acc:32.66 % - Loss:1.8200965452194213 %
# Model4 - Acc:32.82 % - Loss:1.8249163355827331 %
# Model9 - Acc:31.7 % - Loss:1.8304159693717956 %
# Model3 - Acc:32.16 % - Loss:1.8231012697219848 %
# Model8 - Acc:32.36 % - Loss:1.8377048826217652 %
# Model5 - Acc:31.3 % - Loss:1.8457061872482299 %
# Model0 - Acc:31.32 % - Loss:1.83169504237175 %
# Model6 - Acc:32.14 % - Loss:1.8214476022720336 %
# Model7 - Acc:31.12 % - Loss:1.8378550720214843 %
# [DEBUG] set_epoch_messages called → 26 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 26
# [DEBUG] _record epoch=15 → n_messages=26
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 26
#   [Epoch 16/20] ✓  time=36.88s  cumulative=596.07s
#   [Epoch 17/20] threads started …
# Agent 5 start
# Agent 6 start
# Agent 3 start
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Agent 7 start
# Agent 8 start
# Agent 0 start
# Model5 - Acc:33.64 % - Loss:1.7941703066825867 %
# Model6 - Acc:33.9 % - Loss:1.7647831146717072 %
# Model4 - Acc:34.36 % - Loss:1.768685308456421 %
# Model3 - Acc:34.08 % - Loss:1.7593361678123474 %
# Model1 - Acc:34.3 % - Loss:1.7655530431270599 %
# Model9 - Acc:32.6 % - Loss:1.7824903812408448 %
# Model2 - Acc:34.34 % - Loss:1.7729150879383087 %
# Model7 - Acc:33.84 % - Loss:1.783051373720169 %
# Model8 - Acc:34.06 % - Loss:1.7804997925758361 %
# Model0 - Acc:33.2 % - Loss:1.7773360488414764 %
# [DEBUG] set_epoch_messages called → 34 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 34
# [DEBUG] _record epoch=16 → n_messages=34
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 34
#   [Epoch 17/20] ✓  time=39.02s  cumulative=635.08s
#   [Epoch 18/20] threads started …
# Agent 7 start
# Agent 0 start
# Agent 8 start
# Agent 6 start
# Agent 5 start
# Agent 3 start
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Agent 2 start
# Model7 - Acc:34.54 % - Loss:1.752979505300522 %
# Model0 - Acc:34.82 % - Loss:1.731927798986435 %
# Model8 - Acc:35.76 % - Loss:1.739169445514679 %
# Model6 - Acc:36.22 % - Loss:1.714426278114319 %
# Model5 - Acc:34.56 % - Loss:1.7533841145038604 %
# Model3 - Acc:36.58 % - Loss:1.7166526563167572 %
# Model4 - Acc:36.18 % - Loss:1.718434945344925 %
# Model1 - Acc:35.76 % - Loss:1.727100972175598 %
# Model9 - Acc:35.44 % - Loss:1.7289936408996582 %
# Model2 - Acc:35.52 % - Loss:1.7251499898433684 %
# [DEBUG] set_epoch_messages called → 18 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
# [DEBUG] _record epoch=17 → n_messages=18
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 18
#   [Epoch 18/20] ✓  time=37.33s  cumulative=672.41s
#   [Epoch 19/20] threads started …
# Agent 1 start
# Agent 8 start
# Agent 2 start
# Agent 9 start
# Agent 0 start
# Agent 7 start
# Agent 3 start
# Agent 4 start
# Agent 6 start
# Agent 5 start
# Model1 - Acc:37.02 % - Loss:1.6837588539123536 %
# Model8 - Acc:37.84 % - Loss:1.685488403081894 %
# Model2 - Acc:37.48 % - Loss:1.6818406944274902 %
# Model9 - Acc:36.98 % - Loss:1.69665398144722 %
# Model0 - Acc:36.82 % - Loss:1.7061161794662476 %
# Model7 - Acc:36.32 % - Loss:1.7021549661159516 %
# Model3 - Acc:37.52 % - Loss:1.682650285243988 %
# Model4 - Acc:37.32 % - Loss:1.6922679319381715 %
# Model6 - Acc:37.82 % - Loss:1.6727510735988618 %
# Model5 - Acc:36.0 % - Loss:1.7199192616939545 %
# [DEBUG] set_epoch_messages called → 32 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 32
# [DEBUG] _record epoch=18 → n_messages=32
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 32
#   [Epoch 19/20] ✓  time=38.44s  cumulative=710.85s
#   [Epoch 20/20] threads started …
# Agent 3 start
# Agent 2 start
# Agent 4 start
# Agent 1 start
# Agent 9 start
# Agent 6 start
# Agent 0 start
# Agent 8 start
# Agent 7 start
# Agent 5 start
# Model2 - Acc:38.42 % - Loss:1.6616407874822616 %
# Model3 - Acc:38.82 % - Loss:1.6484086898565293 %
# Model4 - Acc:38.48 % - Loss:1.6604491791725158 %
# Model1 - Acc:38.48 % - Loss:1.6542295053005218 %
# Model9 - Acc:39.0 % - Loss:1.6621562597751618 %
# Model6 - Acc:39.16 % - Loss:1.6400103781223296 %
# Model0 - Acc:38.86 % - Loss:1.6641770296096803 %
# Model8 - Acc:39.0 % - Loss:1.6568975511789321 %
# Model7 - Acc:39.16 % - Loss:1.6716248290538789 %
# Model5 - Acc:38.1 % - Loss:1.686806610107422 %
# [DEBUG] set_epoch_messages called → 22 messages
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
# [DEBUG] _record epoch=19 → n_messages=22
# [DEBUG] _resolve_n_messages → _epoch_n_messages = 22
#   [Epoch 20/20] ✓  time=38.73s  cumulative=749.58s
#
# ──────────────────────────────────────────────────
#   Training complete — <EpochTimer epochs=20 | total=749.58s | mean=37.48s/ep | fastest=ep9(35.47s) | slowest=ep1(51.13s)>
# ──────────────────────────────────────────────────
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_random_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 39.28%
#   Val Loss  finale : 1.6508
#   Temps total      : 749.58s
#   Temps moyen/ép.  : 37.48s
#   Époque la + rapide : ép.9 (35.47s)
#   Époque la + lente  : ép.1 (51.13s)
# ═══════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 131.513 MB
#     Total messages    : 556
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 22.54 ms
#     Synchro totale    : 450.7 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 131.513 MB
#     Total messages    : 556
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 22.54 ms
#     Synchro totale    : 450.7 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ════════════════════════════════════════════════════════════
#   CLASSEMENT FINAL — comparator.rank()
# ════════════════════════════════════════════════════════════
#
# ══════════════════════════════════════════════════════════════════════
#   CLASSEMENT DES MÉTHODES PAR EFFICACITÉ (accuracy / MB)
# ──────────────────────────────────────────────────────────────────────
#   Rang  Méthode                   Total MB     Synchro moy    Efficacité
# ──────────────────────────────────────────────────────────────────────
#   1     Sequential_AC_connected_graph 425.761      153.22         N/A
#   2     Sequential_AC_cycle_graph 94.614       33.33          N/A
#   3     Sequential_AC_graph       85.152       41.97          N/A
#   4     Sequential_AC_random_graph 131.513      22.54          N/A
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Méthode                          Val Loss    Val Acc  Train Acc
# ======================================================================
# Sequential_AC_connected_graph      1.4210     48.03%     46.72%
# Sequential_AC_cycle_graph          1.6749     37.55%     37.34%
# Sequential_AC_graph                1.5719     41.66%     42.08%
# Sequential_AC_random_graph         1.6508     39.28%     38.86%
# ======================================================================
#
# ══════════════════════════════════════════════════════════════════════
#   CLASSEMENT DES MÉTHODES PAR EFFICACITÉ (accuracy / MB)
# ──────────────────────────────────────────────────────────────────────
#   Rang  Méthode                   Total MB     Synchro moy    Efficacité
# ──────────────────────────────────────────────────────────────────────
#   1     Sequential_AC_connected_graph 425.761      153.22         N/A
#   2     Sequential_AC_cycle_graph 94.614       33.33          N/A
#   3     Sequential_AC_graph       85.152       41.97          N/A
#   4     Sequential_AC_random_graph 131.513      22.54          N/A
# ══════════════════════════════════════════════════════════════════════
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_connected_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 48.03%
#   Val Loss  finale : 1.4210
#   Temps total      : 1335.53s
#   Temps moyen/ép.  : 66.78s
#   Époque la + rapide : ép.20 (58.21s)
#   Époque la + lente  : ép.1 (76.74s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_connected_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 425.761 MB
#     Total messages    : 1,800
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 153.22 ms
#     Synchro totale    : 3064.3 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_cycle_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 37.55%
#   Val Loss  finale : 1.6749
#   Temps total      : 1190.58s
#   Temps moyen/ép.  : 59.53s
#   Époque la + rapide : ép.20 (53.33s)
#   Époque la + lente  : ép.10 (65.03s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_cycle_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 94.614 MB
#     Total messages    : 400
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 33.33 ms
#     Synchro totale    : 666.5 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 41.66%
#   Val Loss  finale : 1.5719
#   Temps total      : 1205.59s
#   Temps moyen/ép.  : 60.28s
#   Époque la + rapide : ép.19 (48.88s)
#   Époque la + lente  : ép.17 (73.96s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 85.152 MB
#     Total messages    : 360
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 41.97 ms
#     Synchro totale    : 839.4 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════
#
#
# ═══════════════════════════════════════════════════════
#   RunResult : Sequential_AC_random_graph
# ───────────────────────────────────────────────────────
#   Accuracy  finale : 39.28%
#   Val Loss  finale : 1.6508
#   Temps total      : 749.58s
#   Temps moyen/ép.  : 37.48s
#   Époque la + rapide : ép.9 (35.47s)
#   Époque la + lente  : ép.1 (51.13s)
# ═══════════════════════════════════════════════════════
# ══════════════════════════════════════════════════════════
#   CommunicationCostMetric — Sequential_AC_random_graph
# ──────────────────────────────────────────────────────────
#   Agents              : 10
#   Paramètres/modèle   : 62,006
#   Époques mesurées    : 20
# ──────────────────────────────────────────────────────────
#   VOLUME
#     Octets/message    : 242.2 KB
#     Total échangé     : 131.513 MB
#     Total messages    : 556
# ──────────────────────────────────────────────────────────
#   TEMPS
#     Synchro moy./ép.  : 22.54 ms
#     Synchro totale    : 450.7 ms
# ──────────────────────────────────────────────────────────
#   EFFICACITÉ
#     Accuracy finale   : N/A
#     Score efficacité  : N/A
#     Coût/point acc.   : N/A
# ══════════════════════════════════════════════════════════

# %%
comparator.rank()

# %%
plot_cumulative_times(results)
plot_epoch_times(results)

# %%
comparator.plot_comparison()

# %%
print_benchmark_summary(results)

# %%
plot_all_benchmark_metrics(results)

# %%
plot_average_distance(results)

# %%
for result in results:
    print(f"\n── {result.method_name} ──")
    print(result)
    result.comm_cost.summary()

    plot_cosine_similarity(result)
    plot_distance_heatmap(result.agent_list, result.method_name)
    plot_all_agent_node_weight_metric(result.agent_list)

    result.metrics.plot_history()

# %%
def Average_consensus_fully_connected_graph_k(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.fully_connected_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


def Average_consensus_cycle_graph_k(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.cycle_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


def Average_consensus_star_graph_k(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.star_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


def Average_consensus_random_graph_k(
        agent_list, graph, k, epoch, num_epochs, comm_cost=None):

    graph = NetworkTopology.random_graph(len(agent_list))

    Average_consensus_algorithm_K(
        agent_list,
        graph,
        K=k,
        comm_cost=comm_cost
    )


# ──────────────────────────────────────────────────────────────
# Dictionnaire des méthodes à comparer
# ──────────────────────────────────────────────────────────────

COMMUNICATION_METHODS = {

    "AC_fully_connected_graph":
        Average_consensus_fully_connected_graph_k,

    "AC_cycle_graph":
        Average_consensus_cycle_graph_k,

    "AC_star_graph":
        Average_consensus_star_graph_k,

    "AC_random_graph":
        Average_consensus_random_graph_k,
}


# Device configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent_list = generate_agent(BATCH_SIZE, N_AGENT, DEVICE)

results, comparator = benchmark_sequential(
    communication_methods=COMMUNICATION_METHODS,
    num_epochs=NUM_EPOCHES,
    graph=none,
    k=k,
    BATCH_SIZE=BATCH_SIZE,
    N_AGENT=N_AGENT,
    DEVICE=DEVICE,
)

print_benchmark_summary(results)
comparator.rank()
plot_all_benchmark_metrics(results)
plot_average_distance(results)
plot_cumulative_times(results)
plot_epoch_times(results)

for result in results:
    print(result)
    plot_cosine_similarity(result)
    plot_distance_heatmap(result.agent_list, result.method_name)
    plot_all_agent_node_weight_metric(result.agent_list)

    result.metrics.plot_history()
    result.comm_cost.summary()
