# %% [markdown]
# # PyTorch

# %%
import numpy as np
import torch

# %%
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
torch.randn(1000, 1000)
# Out:
# tensor([[-0.6071,  0.0539,  0.8450,  ..., -0.5482,  0.0851, -0.2365],
#         [ 1.0559,  1.6202,  0.6247,  ...,  0.5285, -0.7490,  0.5348],
#         [ 0.4440,  0.2404, -0.4649,  ...,  0.2057, -1.4231,  1.5198],
#         ...,
#         [ 1.4292, -0.7834, -1.1866,  ...,  0.3862, -0.6562,  0.2524],
#         [ 0.0131,  1.0205,  0.2356,  ..., -0.3969, -0.7766,  0.3878],
#         [ 1.4423, -1.9087, -1.4529,  ...,  0.6783, -0.6220,  1.3263]])

# %%
A = torch.from_numpy(np.array([[2., 3.], [1., 0]]))
B = torch.from_numpy(np.array([[1., 2.], [3.,4.]]))

C = torch.matmul(C,D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 A = torch.from_numpy(np.array([[2., 3.], [1., 0]]))
#       2 B = torch.from_numpy(np.array([[1., 2.], [3.,4.]]))
#       3
# ----> 4 C = torch.matmul(C,D)
#
# NameError: name 'C' is not defined

# %%
# Out:
# 2.11.0+cpu

# %%
C
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 C
#
# NameError: name 'C' is not defined
